# %%
#! pip install langdetect rapidfuzz cleantext

# %%
import os #interaction with the operating system
import pandas as pd #for data manipulation, use pd when referring to panda
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import requests #library for HTTP requests, used to retrieve data from web APIs
import nltk #NLTK=Natural Language ToolKit, for working with text data, used for text processing such as tokenizatino, stemming, tagging, ...
from collections import namedtuple #import tuple library from the collections module
from nltk.corpus import brown #import brown from the nltk module, collection of english text
import time #work with time-related functions, e.g., execution time
import re #regular expression library, support for searching, matching and manipulating strings
import urllib.parse #parsing URLs, splitting them into components
import html #for decoding HTML entities to convert them back to normal characters
import re #for cleaning and removing

from langdetect import detect, DetectorFactory
from tqdm import tqdm
from rapidfuzz import fuzz
from cleantext import clean

# %%
# Ensure NLTK resources are downloaded
nltk.download('brown') #Brown Corpus of the nltk toolkit is downloaded, this is A dataset of text that is commonly used in NLP tasks

# Define helper functions
def to_abstract(paper): 
    if 'abstract_inverted_index' in paper and paper['abstract_inverted_index'] is not None: #Check to see if the value of the key is None
        #return ' '.join(paper['abstract_inverted_index'].keys())
        word_index = []
        for k,v in paper['abstract_inverted_index'].items():
            for index in v:
                word_index.append([k,index])
    
        word_index = sorted(word_index,key = lambda x : x[1])
    
        word_list = []
        for i in range(len(word_index)):
            word_list.append(word_index[i][0])
    
        separator = ' '
        reconstructed_text = separator.join(word_list)
    
        return reconstructed_text
    else:
        return ''
        

def is_english(text, brown_corpus, threshold=0.5): #threshold determines the minimum percentage of English words
    """Determine if the given text is in English."""
    if not text:
        return 'EMPTY', 'NA'

    try:
        tokens = set(re.findall(r"\w+", text.lower()))
        if not tokens:
            return 'EMPTY', 'NA'

        lang_ratio = len(tokens & brown_corpus.value) / len(tokens)
        return 'PASS', 'en' if lang_ratio > threshold else 'non-en'
    except Exception as e:
        return 'FAIL', str(e)

# Clean text and decode HTML entities
def clean_text(text):
    """Clean text by decoding HTML entities and fixing encoding issues."""
    text = html.unescape(text)
    # Remove HTML tags
    text = re.sub(r'<[^>]+>', '', text)  # Removes anything in angle brackets, e.g., <div>, <h>
    # Remove specific unwanted prefixes, e.g., "e17029 Background:"
    text = re.sub(r'\b[e0-9]+\s+Background:\s*', '', text)  # Remove patterns like "e17029 Background:"

    # Encode in 'latin1' (ISO-8859-1) and decode to 'utf-8' to fix special characters
    try:
      text = text.encode('latin1').decode('utf-8')
    except (UnicodeEncodeError, UnicodeDecodeError):
      pass

    return text

def format_ids(items, base_url):
    """Format IDs from a list of items."""
    return '|'.join([item['id'].replace(base_url, '') for item in items if 'id' in item])

def format_authors(authorships):
    """Extract author names from the authorship field."""
    # Clean author names with clean_text()
    return ', '.join([clean_text(authorship['author']['display_name']) for authorship in authorships if 'author' in authorship])

def format_citations(referenced_works):
    """Extract and format citations (referenced works) from the paper."""
    return '|'.join([ref_work.replace('https://openalex.org/W', '') for ref_work in referenced_works])

def fetch_articles(base_url, headers):
    """Fetch articles from the OpenAlex API."""
    cursor = '*'
    papers_list = []
    i = 0

    while cursor:
        full_url = f"{base_url}&per_page=100&cursor={cursor}"
        print(f"Fetching results ({i})...")
        i = i+100

        response = requests.get(full_url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            if 'results' in data and data['results']:
                for paper in data['results']:
                    # Check if paper is None
                    if paper is None:
                        print("Skipping None paper") # Print a message to identify skipped papers
                        continue # Skip to the next paper

                    abstract = to_abstract(paper)
                    title = paper.get('title', '')

                    # Check if title is None or empty before calling replace
                    if title:
                        title = title.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                    pub_date = paper.get('publication_date', '')
                    pub_year = paper.get('publication_year', '')

                    
                    
                    # Ensure both title and abstract are strings before concatenation
                    if title is None:
                        title = ''
                    if abstract is None:
                        abstract = ''

                    # Clean the title and abstract using clean_text()
                    title = clean_text(title)
                    abstract = clean_text(abstract)

                    status, lang = is_english(title + ' ' + abstract, bc_brown)
                    
                    if lang == 'en' and len(title)>0 and len(abstract)>0:
                    
                        authors = format_authors(paper.get('authorships', []))
                        citations = format_citations(paper.get('referenced_works', []))
                        papers_list.append({
                            'PaperId': paper['id'].replace('https://openalex.org/W', ''),
                            'PaperTitle': title,
                            'Citations': citations,
                            'coFoS': format_ids(paper.get('concepts', []), 'https://openalex.org/C'),
                            'Authors': authors,
                            'Abstract': abstract,
                            'Lang': 'en',
                            'PubYear': pub_year,
                            'PubDate': pub_date
                        })
                cursor = data['meta'].get('next_cursor', None)
            else:
                cursor = None

            time.sleep(1)  # Pause to avoid rate limiting
        else:
            print(f"Request failed with status code {response.status_code}")
            break

    return papers_list
# Out:
# [nltk_data] Downloading package brown to /home/janna/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
# Initialize parameters
Brown = namedtuple("Brown", field_names=['value'])
bc_brown = Brown(value=set(word.lower() for word in brown.words()))
headers = {'email': 'xxx@xxx.xx'}

# %%
# Define search parameters
search_term = '("mental" OR "psychological" OR "behavioural" OR "psychology" OR "psychiatry" OR "neurological" OR "mind" OR "brain" OR "behaviour" OR "psychiatric") \
              AND ("anxiety" OR "depression" OR "psychosis") AND ("treatment" OR "therapy" OR "therapeutic" OR "mechanism" OR "intervention" OR "early" OR "diagnosis" OR "diagnostic" OR "translation")'

publication_year_range = '2015-2025' #10 years
encoded_search_term = urllib.parse.quote(search_term)

base_url = f'https://api.openalex.org/works?filter=has_abstract:true,title_and_abstract.search:{encoded_search_term},publication_year:{publication_year_range}&sort=publication_year:desc'

# Create the output directory if it does not exist
output_dir = './output'
os.makedirs(output_dir, exist_ok=True)

# %%
# Fetch and process articles
papers = fetch_articles(base_url, headers)
# Out:
# Fetching results (0)...
# Fetching results (100)...
# Fetching results (200)...
# Fetching results (300)...
# Fetching results (400)...
# Fetching results (500)...
# Fetching results (600)...
# Fetching results (700)...
# Fetching results (800)...
# Fetching results (900)...
# Fetching results (1000)...
# Fetching results (1100)...
# Fetching results (1200)...
# Fetching results (1300)...
# Fetching results (1400)...
# Fetching results (1500)...
# Fetching results (1600)...
# Fetching results (1700)...
# Fetching results (1800)...
# Fetching results (1900)...
# Fetching results (2000)...
# Fetching results (2100)...
# Fetching results (2200)...
# Fetching results (2300)...
# Fetching results (2400)...
# Fetching results (2500)...
# Fetching results (2600)...
# Fetching results (2700)...
# Fetching results (2800)...
# Fetching results (2900)...
# Fetching results (3000)...
# Fetching results (3100)...
# Fetching results (3200)...
# Fetching results (3300)...
# Fetching results (3400)...
# Fetching results (3500)...
# Fetching results (3600)...
# Fetching results (3700)...
# Fetching results (3800)...
# Fetching results (3900)...
# Fetching results (4000)...
# Fetching results (4100)...
# Fetching results (4200)...
# Fetching results (4300)...
# Fetching results (4400)...
# Fetching results (4500)...
# Fetching results (4600)...
# Fetching results (4700)...
# Fetching results (4800)...
# Fetching results (4900)...
# Fetching results (5000)...
# Fetching results (5100)...
# Fetching results (5200)...
# Fetching results (5300)...
# Fetching results (5400)...
# Fetching results (5500)...
# Fetching results (5600)...
# Fetching results (5700)...
# Fetching results (5800)...
# Fetching results (5900)...
# Fetching results (6000)...
# Fetching results (6100)...
# Fetching results (6200)...
# Fetching results (6300)...
# Fetching results (6400)...
# Fetching results (6500)...
# Fetching results (6600)...
# Fetching results (6700)...
# Fetching results (6800)...
# Fetching results (6900)...
# Fetching results (7000)...
# Fetching results (7100)...
# Fetching results (7200)...
# Fetching results (7300)...
# Fetching results (7400)...
# Fetching results (7500)...
# Fetching results (7600)...
# Fetching results (7700)...
# Fetching results (7800)...
# Fetching results (7900)...
# Fetching results (8000)...
# Fetching results (8100)...
# Fetching results (8200)...
# Fetching results (8300)...
# Fetching results (8400)...
# Fetching results (8500)...
# Fetching results (8600)...
# Fetching results (8700)...
# Fetching results (8800)...
# Fetching results (8900)...
# Fetching results (9000)...
# Fetching results (9100)...
# Fetching results (9200)...
# Fetching results (9300)...
# Fetching results (9400)...
# Fetching results (9500)...
# Fetching results (9600)...
# Fetching results (9700)...
# Fetching results (9800)...
# Fetching results (9900)...
# Fetching results (10000)...
# Fetching results (10100)...
# Fetching results (10200)...
# Fetching results (10300)...
# Fetching results (10400)...
# Fetching results (10500)...
# Fetching results (10600)...
# Fetching results (10700)...
# Fetching results (10800)...
# Fetching results (10900)...
# Fetching results (11000)...
# Fetching results (11100)...
# Fetching results (11200)...
# Fetching results (11300)...
# Fetching results (11400)...
# Fetching results (11500)...
# Fetching results (11600)...
# Fetching results (11700)...
# Fetching results (11800)...
# Fetching results (11900)...
# Fetching results (12000)...
# Fetching results (12100)...
# Fetching results (12200)...
# Fetching results (12300)...
# Fetching results (12400)...
# Fetching results (12500)...
# Fetching results (12600)...
# Fetching results (12700)...
# Fetching results (12800)...
# Fetching results (12900)...
# Fetching results (13000)...
# Fetching results (13100)...
# Fetching results (13200)...
# Fetching results (13300)...
# Fetching results (13400)...
# Fetching results (13500)...
# Fetching results (13600)...
# Fetching results (13700)...
# Fetching results (13800)...
# Fetching results (13900)...
# Fetching results (14000)...
# Fetching results (14100)...
# Fetching results (14200)...
# Fetching results (14300)...
# Fetching results (14400)...
# Fetching results (14500)...
# Fetching results (14600)...
# Fetching results (14700)...
# Fetching results (14800)...
# Fetching results (14900)...
# Fetching results (15000)...
# Fetching results (15100)...
# Fetching results (15200)...
# Fetching results (15300)...
# Fetching results (15400)...
# Fetching results (15500)...
# Fetching results (15600)...
# Fetching results (15700)...
# Fetching results (15800)...
# Fetching results (15900)...
# Fetching results (16000)...
# Fetching results (16100)...
# Fetching results (16200)...
# Fetching results (16300)...
# Fetching results (16400)...
# Fetching results (16500)...
# Fetching results (16600)...
# Fetching results (16700)...
# Fetching results (16800)...
# Fetching results (16900)...
# Fetching results (17000)...
# Fetching results (17100)...
# Fetching results (17200)...
# Fetching results (17300)...
# Fetching results (17400)...
# Fetching results (17500)...
# Fetching results (17600)...
# Fetching results (17700)...
# Fetching results (17800)...
# Fetching results (17900)...
# Fetching results (18000)...
# Fetching results (18100)...
# Fetching results (18200)...
# Fetching results (18300)...
# Fetching results (18400)...
# Fetching results (18500)...
# Fetching results (18600)...
# Fetching results (18700)...
# Fetching results (18800)...
# Fetching results (18900)...
# Fetching results (19000)...
# Fetching results (19100)...
# Fetching results (19200)...
# Fetching results (19300)...
# Fetching results (19400)...
# Fetching results (19500)...
# Fetching results (19600)...
# Fetching results (19700)...
# Fetching results (19800)...
# Fetching results (19900)...
# Fetching results (20000)...
# Fetching results (20100)...
# Fetching results (20200)...
# Fetching results (20300)...
# Fetching results (20400)...
# Fetching results (20500)...
# Fetching results (20600)...
# Fetching results (20700)...
# Fetching results (20800)...
# Fetching results (20900)...
# Fetching results (21000)...
# Fetching results (21100)...
# Fetching results (21200)...
# Fetching results (21300)...
# Fetching results (21400)...
# Fetching results (21500)...
# Fetching results (21600)...
# Fetching results (21700)...
# Fetching results (21800)...
# Fetching results (21900)...
# Fetching results (22000)...
# Fetching results (22100)...
# Fetching results (22200)...
# Fetching results (22300)...
# Fetching results (22400)...
# Fetching results (22500)...
# Fetching results (22600)...
# Fetching results (22700)...
# Fetching results (22800)...
# Fetching results (22900)...
# Fetching results (23000)...
# Fetching results (23100)...
# Fetching results (23200)...
# Fetching results (23300)...
# Fetching results (23400)...
# Fetching results (23500)...
# Fetching results (23600)...
# Fetching results (23700)...
# Fetching results (23800)...
# Fetching results (23900)...
# Fetching results (24000)...
# Fetching results (24100)...
# Fetching results (24200)...
# Fetching results (24300)...
# Fetching results (24400)...
# Fetching results (24500)...
# Fetching results (24600)...
# Fetching results (24700)...
# Fetching results (24800)...
# Fetching results (24900)...
# Fetching results (25000)...
# Fetching results (25100)...
# Fetching results (25200)...
# Fetching results (25300)...
# Fetching results (25400)...
# Fetching results (25500)...
# Fetching results (25600)...
# Fetching results (25700)...
# Fetching results (25800)...
# Fetching results (25900)...
# Fetching results (26000)...
# Fetching results (26100)...
# Fetching results (26200)...
# Fetching results (26300)...
# Fetching results (26400)...
# Fetching results (26500)...
# Fetching results (26600)...
# Fetching results (26700)...
# Fetching results (26800)...
# Fetching results (26900)...
# Fetching results (27000)...
# Fetching results (27100)...
# Fetching results (27200)...
# Fetching results (27300)...
# Fetching results (27400)...
# Fetching results (27500)...
# Fetching results (27600)...
# Fetching results (27700)...
# Fetching results (27800)...
# Fetching results (27900)...
# Fetching results (28000)...
# Fetching results (28100)...
# Fetching results (28200)...
# Fetching results (28300)...
# Fetching results (28400)...
# Fetching results (28500)...
# Fetching results (28600)...
# Fetching results (28700)...
# Fetching results (28800)...
# Fetching results (28900)...
# Fetching results (29000)...
# Fetching results (29100)...
# Fetching results (29200)...
# Fetching results (29300)...
# Fetching results (29400)...
# Fetching results (29500)...
# Fetching results (29600)...
# Fetching results (29700)...
# Fetching results (29800)...
# Fetching results (29900)...
# Fetching results (30000)...
# Fetching results (30100)...
# Fetching results (30200)...
# Fetching results (30300)...
# Fetching results (30400)...
# Fetching results (30500)...
# Fetching results (30600)...
# Fetching results (30700)...
# Fetching results (30800)...
# Fetching results (30900)...
# Fetching results (31000)...
# Fetching results (31100)...
# Fetching results (31200)...
# Fetching results (31300)...
# Fetching results (31400)...
# Fetching results (31500)...
# Fetching results (31600)...
# Fetching results (31700)...
# Fetching results (31800)...
# Fetching results (31900)...
# Fetching results (32000)...
# Fetching results (32100)...
# Fetching results (32200)...
# Fetching results (32300)...
# Fetching results (32400)...
# Fetching results (32500)...
# Fetching results (32600)...
# Fetching results (32700)...
# Fetching results (32800)...
# Fetching results (32900)...
# Fetching results (33000)...
# Fetching results (33100)...
# Fetching results (33200)...
# Fetching results (33300)...
# Fetching results (33400)...
# Fetching results (33500)...
# Fetching results (33600)...
# Fetching results (33700)...
# Fetching results (33800)...
# Fetching results (33900)...
# Fetching results (34000)...
# Fetching results (34100)...
# Fetching results (34200)...
# Fetching results (34300)...
# Fetching results (34400)...
# Fetching results (34500)...
# Fetching results (34600)...
# Fetching results (34700)...
# Fetching results (34800)...
# Fetching results (34900)...
# Fetching results (35000)...
# Fetching results (35100)...
# Fetching results (35200)...
# Fetching results (35300)...
# Fetching results (35400)...
# Fetching results (35500)...
# Fetching results (35600)...
# Fetching results (35700)...
# Fetching results (35800)...
# Fetching results (35900)...
# Fetching results (36000)...
# Fetching results (36100)...
# Fetching results (36200)...
# Fetching results (36300)...
# Fetching results (36400)...
# Fetching results (36500)...
# Fetching results (36600)...
# Fetching results (36700)...
# Fetching results (36800)...
# Fetching results (36900)...
# Fetching results (37000)...
# Fetching results (37100)...
# Fetching results (37200)...
# Fetching results (37300)...
# Fetching results (37400)...
# Fetching results (37500)...
# Fetching results (37600)...
# Fetching results (37700)...
# Fetching results (37800)...
# Fetching results (37900)...
# Fetching results (38000)...
# Fetching results (38100)...
# Fetching results (38200)...
# Fetching results (38300)...
# Fetching results (38400)...
# Fetching results (38500)...
# Fetching results (38600)...
# Fetching results (38700)...
# Fetching results (38800)...
# Fetching results (38900)...
# Fetching results (39000)...
# Fetching results (39100)...
# Fetching results (39200)...
# Fetching results (39300)...
# Fetching results (39400)...
# Fetching results (39500)...
# Fetching results (39600)...
# Fetching results (39700)...
# Fetching results (39800)...
# Fetching results (39900)...
# Fetching results (40000)...
# Fetching results (40100)...
# Fetching results (40200)...
# Fetching results (40300)...
# Fetching results (40400)...
# Fetching results (40500)...
# Fetching results (40600)...
# Fetching results (40700)...
# Fetching results (40800)...
# Fetching results (40900)...
# Fetching results (41000)...
# Fetching results (41100)...
# Fetching results (41200)...
# Fetching results (41300)...
# Fetching results (41400)...
# Fetching results (41500)...
# Fetching results (41600)...
# Fetching results (41700)...
# Fetching results (41800)...
# Fetching results (41900)...
# Fetching results (42000)...
# Fetching results (42100)...
# Fetching results (42200)...
# Fetching results (42300)...
# Fetching results (42400)...
# Fetching results (42500)...
# Fetching results (42600)...
# Fetching results (42700)...
# Fetching results (42800)...
# Fetching results (42900)...
# Fetching results (43000)...
# Fetching results (43100)...
# Fetching results (43200)...
# Fetching results (43300)...
# Fetching results (43400)...
# Fetching results (43500)...
# Fetching results (43600)...
# Fetching results (43700)...
# Fetching results (43800)...
# Fetching results (43900)...
# Fetching results (44000)...
# Fetching results (44100)...
# Fetching results (44200)...
# Fetching results (44300)...
# Fetching results (44400)...
# Fetching results (44500)...
# Fetching results (44600)...
# Fetching results (44700)...
# Fetching results (44800)...
# Fetching results (44900)...
# Fetching results (45000)...
# Fetching results (45100)...
# Fetching results (45200)...
# Fetching results (45300)...
# Fetching results (45400)...
# Fetching results (45500)...
# Fetching results (45600)...
# Fetching results (45700)...
# Fetching results (45800)...
# Fetching results (45900)...
# Fetching results (46000)...
# Fetching results (46100)...
# Fetching results (46200)...
# Fetching results (46300)...
# Fetching results (46400)...
# Fetching results (46500)...
# Fetching results (46600)...
# Fetching results (46700)...
# Fetching results (46800)...
# Fetching results (46900)...
# Fetching results (47000)...
# Fetching results (47100)...
# Fetching results (47200)...
# Fetching results (47300)...
# Fetching results (47400)...
# Fetching results (47500)...
# Fetching results (47600)...
# Fetching results (47700)...
# Fetching results (47800)...
# Fetching results (47900)...
# Fetching results (48000)...
# Fetching results (48100)...
# Fetching results (48200)...
# Fetching results (48300)...
# Fetching results (48400)...
# Fetching results (48500)...
# Fetching results (48600)...
# Fetching results (48700)...
# Fetching results (48800)...
# Fetching results (48900)...
# Fetching results (49000)...
# Fetching results (49100)...
# Fetching results (49200)...
# Fetching results (49300)...
# Fetching results (49400)...
# Fetching results (49500)...
# Fetching results (49600)...
# Fetching results (49700)...
# Fetching results (49800)...
# Fetching results (49900)...
# Fetching results (50000)...
# Fetching results (50100)...
# Fetching results (50200)...
# Fetching results (50300)...
# Fetching results (50400)...
# Fetching results (50500)...
# Fetching results (50600)...
# Fetching results (50700)...
# Fetching results (50800)...
# Fetching results (50900)...
# Fetching results (51000)...
# Fetching results (51100)...
# Fetching results (51200)...
# Fetching results (51300)...
# Fetching results (51400)...
# Fetching results (51500)...
# Fetching results (51600)...
# Fetching results (51700)...
# Fetching results (51800)...
# Fetching results (51900)...
# Fetching results (52000)...
# Fetching results (52100)...
# Fetching results (52200)...
# Fetching results (52300)...
# Fetching results (52400)...
# Fetching results (52500)...
# Fetching results (52600)...
# Fetching results (52700)...
# Fetching results (52800)...
# Fetching results (52900)...
# Fetching results (53000)...
# Fetching results (53100)...
# Fetching results (53200)...
# Fetching results (53300)...
# Fetching results (53400)...
# Fetching results (53500)...
# Fetching results (53600)...
# Fetching results (53700)...
# Fetching results (53800)...
# Fetching results (53900)...
# Fetching results (54000)...
# Fetching results (54100)...
# Fetching results (54200)...
# Fetching results (54300)...
# Fetching results (54400)...
# Fetching results (54500)...
# Fetching results (54600)...
# Fetching results (54700)...
# Fetching results (54800)...
# Fetching results (54900)...
# Fetching results (55000)...
# Fetching results (55100)...
# Fetching results (55200)...
# Fetching results (55300)...
# Fetching results (55400)...
# Fetching results (55500)...
# Fetching results (55600)...
# Fetching results (55700)...
# Fetching results (55800)...
# Fetching results (55900)...
# Fetching results (56000)...
# Fetching results (56100)...
# Fetching results (56200)...
# Fetching results (56300)...
# Fetching results (56400)...
# Fetching results (56500)...
# Fetching results (56600)...
# Fetching results (56700)...
# Fetching results (56800)...
# Fetching results (56900)...
# Fetching results (57000)...
# Fetching results (57100)...
# Fetching results (57200)...
# Fetching results (57300)...
# Fetching results (57400)...
# Fetching results (57500)...
# Fetching results (57600)...
# Fetching results (57700)...
# Fetching results (57800)...
# Fetching results (57900)...
# Fetching results (58000)...
# Fetching results (58100)...
# Fetching results (58200)...
# Fetching results (58300)...
# Fetching results (58400)...
# Fetching results (58500)...
# Fetching results (58600)...
# Fetching results (58700)...
# Fetching results (58800)...
# Fetching results (58900)...
# Fetching results (59000)...
# Fetching results (59100)...
# Fetching results (59200)...
# Fetching results (59300)...
# Fetching results (59400)...
# Fetching results (59500)...
# Fetching results (59600)...
# Fetching results (59700)...
# Fetching results (59800)...
# Fetching results (59900)...
# Fetching results (60000)...
# Fetching results (60100)...
# Fetching results (60200)...
# Fetching results (60300)...
# Fetching results (60400)...
# Fetching results (60500)...
# Fetching results (60600)...
# Fetching results (60700)...
# Fetching results (60800)...
# Fetching results (60900)...
# Fetching results (61000)...
# Fetching results (61100)...
# Fetching results (61200)...
# Fetching results (61300)...
# Fetching results (61400)...
# Fetching results (61500)...
# Fetching results (61600)...
# Fetching results (61700)...
# Fetching results (61800)...
# Fetching results (61900)...
# Fetching results (62000)...
# Fetching results (62100)...
# Fetching results (62200)...
# Fetching results (62300)...
# Fetching results (62400)...
# Fetching results (62500)...
# Fetching results (62600)...
# Fetching results (62700)...
# Fetching results (62800)...
# Fetching results (62900)...
# Fetching results (63000)...
# Fetching results (63100)...
# Fetching results (63200)...
# Fetching results (63300)...
# Fetching results (63400)...
# Fetching results (63500)...
# Fetching results (63600)...
# Fetching results (63700)...
# Fetching results (63800)...
# Fetching results (63900)...
# Fetching results (64000)...
# Fetching results (64100)...
# Fetching results (64200)...
# Fetching results (64300)...
# Fetching results (64400)...
# Fetching results (64500)...
# Fetching results (64600)...
# Fetching results (64700)...
# Fetching results (64800)...
# Fetching results (64900)...
# Fetching results (65000)...
# Fetching results (65100)...
# Fetching results (65200)...
# Fetching results (65300)...
# Fetching results (65400)...
# Fetching results (65500)...
# Fetching results (65600)...
# Fetching results (65700)...
# Fetching results (65800)...
# Fetching results (65900)...
# Fetching results (66000)...
# Fetching results (66100)...
# Fetching results (66200)...
# Fetching results (66300)...
# Fetching results (66400)...
# Fetching results (66500)...
# Fetching results (66600)...
# Fetching results (66700)...
# Fetching results (66800)...
# Fetching results (66900)...
# Fetching results (67000)...
# Fetching results (67100)...
# Fetching results (67200)...
# Fetching results (67300)...
# Fetching results (67400)...
# Fetching results (67500)...
# Fetching results (67600)...
# Fetching results (67700)...
# Fetching results (67800)...
# Fetching results (67900)...
# Fetching results (68000)...
# Fetching results (68100)...
# Fetching results (68200)...
# Fetching results (68300)...
# Fetching results (68400)...
# Fetching results (68500)...
# Fetching results (68600)...
# Fetching results (68700)...
# Fetching results (68800)...
# Fetching results (68900)...
# Fetching results (69000)...
# Fetching results (69100)...
# Fetching results (69200)...
# Fetching results (69300)...
# Fetching results (69400)...
# Fetching results (69500)...
# Fetching results (69600)...
# Fetching results (69700)...
# Fetching results (69800)...
# Fetching results (69900)...
# Fetching results (70000)...
# Fetching results (70100)...
# Fetching results (70200)...
# Fetching results (70300)...
# Fetching results (70400)...
# Fetching results (70500)...
# Fetching results (70600)...
# Fetching results (70700)...
# Fetching results (70800)...
# Fetching results (70900)...
# Fetching results (71000)...
# Fetching results (71100)...
# Fetching results (71200)...
# Fetching results (71300)...
# Fetching results (71400)...
# Fetching results (71500)...
# Fetching results (71600)...
# Fetching results (71700)...
# Fetching results (71800)...
# Fetching results (71900)...
# Fetching results (72000)...
# Fetching results (72100)...
# Fetching results (72200)...
# Fetching results (72300)...
# Fetching results (72400)...
# Fetching results (72500)...
# Fetching results (72600)...
# Fetching results (72700)...
# Fetching results (72800)...
# Fetching results (72900)...
# Fetching results (73000)...
# Fetching results (73100)...
# Fetching results (73200)...
# Fetching results (73300)...
# Fetching results (73400)...
# Fetching results (73500)...
# Fetching results (73600)...
# Fetching results (73700)...
# Fetching results (73800)...
# Fetching results (73900)...
# Fetching results (74000)...
# Fetching results (74100)...
# Fetching results (74200)...
# Fetching results (74300)...
# Fetching results (74400)...
# Fetching results (74500)...
# Fetching results (74600)...
# Fetching results (74700)...
# Fetching results (74800)...
# Fetching results (74900)...
# Fetching results (75000)...
# Fetching results (75100)...
# Fetching results (75200)...
# Fetching results (75300)...
# Fetching results (75400)...
# Fetching results (75500)...
# Fetching results (75600)...
# Fetching results (75700)...
# Fetching results (75800)...
# Fetching results (75900)...
# Fetching results (76000)...
# Fetching results (76100)...
# Fetching results (76200)...
# Fetching results (76300)...
# Fetching results (76400)...
# Fetching results (76500)...
# Fetching results (76600)...
# Fetching results (76700)...
# Fetching results (76800)...
# Fetching results (76900)...
# Fetching results (77000)...
# Fetching results (77100)...
# Fetching results (77200)...
# Fetching results (77300)...
# Fetching results (77400)...
# Fetching results (77500)...
# Fetching results (77600)...
# Fetching results (77700)...
# Fetching results (77800)...
# Fetching results (77900)...
# Fetching results (78000)...
# Fetching results (78100)...
# Fetching results (78200)...
# Fetching results (78300)...
# Fetching results (78400)...
# Fetching results (78500)...
# Fetching results (78600)...
# Fetching results (78700)...
# Fetching results (78800)...
# Fetching results (78900)...
# Fetching results (79000)...
# Fetching results (79100)...
# Fetching results (79200)...
# Fetching results (79300)...
# Fetching results (79400)...
# Fetching results (79500)...
# Fetching results (79600)...
# Fetching results (79700)...
# Fetching results (79800)...
# Fetching results (79900)...
# Fetching results (80000)...
# Fetching results (80100)...
# Fetching results (80200)...
# Fetching results (80300)...
# Fetching results (80400)...
# Fetching results (80500)...
# Fetching results (80600)...
# Fetching results (80700)...
# Fetching results (80800)...
# Fetching results (80900)...
# Fetching results (81000)...
# Fetching results (81100)...
# Fetching results (81200)...
# Fetching results (81300)...
# Fetching results (81400)...
# Fetching results (81500)...
# Fetching results (81600)...
# Fetching results (81700)...
# Fetching results (81800)...
# Fetching results (81900)...
# Fetching results (82000)...
# Fetching results (82100)...
# Fetching results (82200)...
# Fetching results (82300)...
# Fetching results (82400)...
# Fetching results (82500)...
# Fetching results (82600)...
# Fetching results (82700)...
# Fetching results (82800)...
# Fetching results (82900)...
# Fetching results (83000)...
# Fetching results (83100)...
# Fetching results (83200)...
# Fetching results (83300)...
# Fetching results (83400)...
# Fetching results (83500)...
# Fetching results (83600)...
# Fetching results (83700)...
# Fetching results (83800)...
# Fetching results (83900)...
# Fetching results (84000)...
# Fetching results (84100)...
# Fetching results (84200)...
# Fetching results (84300)...
# Fetching results (84400)...
# Fetching results (84500)...
# Fetching results (84600)...
# Fetching results (84700)...
# Fetching results (84800)...
# Fetching results (84900)...
# Fetching results (85000)...
# Fetching results (85100)...
# Fetching results (85200)...
# Fetching results (85300)...
# Fetching results (85400)...
# Fetching results (85500)...
# Fetching results (85600)...
# Fetching results (85700)...
# Fetching results (85800)...
# Fetching results (85900)...
# Fetching results (86000)...
# Fetching results (86100)...
# Fetching results (86200)...
# Fetching results (86300)...
# Fetching results (86400)...
# Fetching results (86500)...
# Fetching results (86600)...
# Fetching results (86700)...
# Fetching results (86800)...
# Fetching results (86900)...
# Fetching results (87000)...
# Fetching results (87100)...
# Fetching results (87200)...
# Fetching results (87300)...
# Fetching results (87400)...
# Fetching results (87500)...
# Fetching results (87600)...
# Fetching results (87700)...
# Fetching results (87800)...
# Fetching results (87900)...
# Fetching results (88000)...
# Fetching results (88100)...
# Fetching results (88200)...
# Fetching results (88300)...
# Fetching results (88400)...
# Fetching results (88500)...
# Fetching results (88600)...
# Fetching results (88700)...
# Fetching results (88800)...
# Fetching results (88900)...
# Fetching results (89000)...
# Fetching results (89100)...
# Fetching results (89200)...
# Fetching results (89300)...
# Fetching results (89400)...
# Fetching results (89500)...
# Fetching results (89600)...
# Fetching results (89700)...
# Fetching results (89800)...
# Fetching results (89900)...
# Fetching results (90000)...
# Fetching results (90100)...
# Fetching results (90200)...
# Fetching results (90300)...
# Fetching results (90400)...
# Fetching results (90500)...
# Fetching results (90600)...
# Fetching results (90700)...
# Fetching results (90800)...
# Fetching results (90900)...
# Fetching results (91000)...
# Fetching results (91100)...
# Fetching results (91200)...
# Fetching results (91300)...
# Fetching results (91400)...
# Fetching results (91500)...
# Fetching results (91600)...
# Fetching results (91700)...
# Fetching results (91800)...
# Fetching results (91900)...
# Fetching results (92000)...
# Fetching results (92100)...
# Fetching results (92200)...
# Fetching results (92300)...
# Fetching results (92400)...
# Fetching results (92500)...
# Fetching results (92600)...
# Fetching results (92700)...
# Fetching results (92800)...
# Fetching results (92900)...
# Fetching results (93000)...
# Fetching results (93100)...
# Fetching results (93200)...
# Fetching results (93300)...
# Fetching results (93400)...
# Fetching results (93500)...
# Fetching results (93600)...
# Fetching results (93700)...
# Fetching results (93800)...
# Fetching results (93900)...
# Fetching results (94000)...
# Fetching results (94100)...
# Fetching results (94200)...
# Fetching results (94300)...
# Fetching results (94400)...
# Fetching results (94500)...
# Fetching results (94600)...
# Fetching results (94700)...
# Fetching results (94800)...
# Fetching results (94900)...
# Fetching results (95000)...
# Fetching results (95100)...
# Fetching results (95200)...
# Fetching results (95300)...
# Fetching results (95400)...
# Fetching results (95500)...
# Fetching results (95600)...
# Fetching results (95700)...
# Fetching results (95800)...
# Fetching results (95900)...
# Fetching results (96000)...
# Fetching results (96100)...
# Fetching results (96200)...
# Fetching results (96300)...
# Fetching results (96400)...
# Fetching results (96500)...
# Fetching results (96600)...
# Fetching results (96700)...
# Fetching results (96800)...
# Fetching results (96900)...
# Fetching results (97000)...
# Fetching results (97100)...
# Fetching results (97200)...
# Fetching results (97300)...
# Fetching results (97400)...
# Fetching results (97500)...
# Fetching results (97600)...
# Fetching results (97700)...
# Fetching results (97800)...
# Fetching results (97900)...
# Fetching results (98000)...
# Fetching results (98100)...
# Fetching results (98200)...
# Fetching results (98300)...
# Fetching results (98400)...
# Fetching results (98500)...
# Fetching results (98600)...
# Fetching results (98700)...
# Fetching results (98800)...
# Fetching results (98900)...
# Fetching results (99000)...
# Fetching results (99100)...
# Fetching results (99200)...
# Fetching results (99300)...
# Fetching results (99400)...
# Fetching results (99500)...
# Fetching results (99600)...
# Fetching results (99700)...
# Fetching results (99800)...
# Fetching results (99900)...
# Fetching results (100000)...
# Fetching results (100100)...
# Fetching results (100200)...
# Fetching results (100300)...
# Fetching results (100400)...
# Fetching results (100500)...
# Fetching results (100600)...
# Fetching results (100700)...
# Fetching results (100800)...
# Fetching results (100900)...
# Fetching results (101000)...
# Fetching results (101100)...
# Fetching results (101200)...
# Fetching results (101300)...
# Fetching results (101400)...
# Fetching results (101500)...
# Fetching results (101600)...
# Fetching results (101700)...
# Fetching results (101800)...
# Fetching results (101900)...
# Fetching results (102000)...
# Fetching results (102100)...
# Fetching results (102200)...
# Fetching results (102300)...
# Fetching results (102400)...
# Fetching results (102500)...
# Fetching results (102600)...
# Fetching results (102700)...
# Fetching results (102800)...
# Fetching results (102900)...
# Fetching results (103000)...
# Fetching results (103100)...
# Fetching results (103200)...
# Fetching results (103300)...
# Fetching results (103400)...
# Fetching results (103500)...
# Fetching results (103600)...
# Fetching results (103700)...
# Fetching results (103800)...
# Fetching results (103900)...
# Fetching results (104000)...
# Fetching results (104100)...
# Fetching results (104200)...
# Fetching results (104300)...
# Fetching results (104400)...
# Fetching results (104500)...
# Fetching results (104600)...
# Fetching results (104700)...
# Fetching results (104800)...
# Fetching results (104900)...
# Fetching results (105000)...
# Fetching results (105100)...
# Fetching results (105200)...
# Fetching results (105300)...
# Fetching results (105400)...
# Fetching results (105500)...
# Fetching results (105600)...
# Fetching results (105700)...
# Fetching results (105800)...
# Fetching results (105900)...
# Fetching results (106000)...
# Fetching results (106100)...
# Fetching results (106200)...
# Fetching results (106300)...
# Fetching results (106400)...
# Fetching results (106500)...
# Fetching results (106600)...
# Fetching results (106700)...
# Fetching results (106800)...
# Fetching results (106900)...
# Fetching results (107000)...
# Fetching results (107100)...
# Fetching results (107200)...
# Fetching results (107300)...
# Fetching results (107400)...
# Fetching results (107500)...
# Fetching results (107600)...
# Fetching results (107700)...
# Fetching results (107800)...
# Fetching results (107900)...
# Fetching results (108000)...
# Fetching results (108100)...
# Fetching results (108200)...
# Fetching results (108300)...
# Fetching results (108400)...
# Fetching results (108500)...
# Fetching results (108600)...
# Fetching results (108700)...
# Fetching results (108800)...
# Fetching results (108900)...
# Fetching results (109000)...
# Fetching results (109100)...
# Fetching results (109200)...
# Fetching results (109300)...
# Fetching results (109400)...
# Fetching results (109500)...
# Fetching results (109600)...
# Fetching results (109700)...
# Fetching results (109800)...
# Fetching results (109900)...
# Fetching results (110000)...
# Fetching results (110100)...
# Fetching results (110200)...
# Fetching results (110300)...
# Fetching results (110400)...
# Fetching results (110500)...
# Fetching results (110600)...
# Fetching results (110700)...
# Fetching results (110800)...
# Fetching results (110900)...
# Fetching results (111000)...
# Fetching results (111100)...
# Fetching results (111200)...
# Fetching results (111300)...
# Fetching results (111400)...
# Fetching results (111500)...
# Fetching results (111600)...
# Fetching results (111700)...
# Fetching results (111800)...
# Fetching results (111900)...
# Fetching results (112000)...
# Fetching results (112100)...
# Fetching results (112200)...
# Fetching results (112300)...
# Fetching results (112400)...
# Fetching results (112500)...
# Fetching results (112600)...
# Fetching results (112700)...
# Fetching results (112800)...
# Fetching results (112900)...
# Fetching results (113000)...
# Fetching results (113100)...
# Fetching results (113200)...
# Fetching results (113300)...
# Fetching results (113400)...
# Fetching results (113500)...
# Fetching results (113600)...
# Fetching results (113700)...
# Fetching results (113800)...
# Fetching results (113900)...
# Fetching results (114000)...
# Fetching results (114100)...
# Fetching results (114200)...
# Fetching results (114300)...
# Fetching results (114400)...
# Fetching results (114500)...
# Fetching results (114600)...
# Fetching results (114700)...
# Fetching results (114800)...
# Fetching results (114900)...
# Fetching results (115000)...
# Fetching results (115100)...
# Fetching results (115200)...
# Fetching results (115300)...
# Fetching results (115400)...
# Fetching results (115500)...
# Fetching results (115600)...
# Fetching results (115700)...
# Fetching results (115800)...
# Fetching results (115900)...
# Fetching results (116000)...
# Fetching results (116100)...
# Fetching results (116200)...
# Fetching results (116300)...
# Fetching results (116400)...
# Fetching results (116500)...
# Fetching results (116600)...
# Fetching results (116700)...
# Fetching results (116800)...
# Fetching results (116900)...
# Fetching results (117000)...
# Fetching results (117100)...
# Fetching results (117200)...
# Fetching results (117300)...
# Fetching results (117400)...
# Fetching results (117500)...
# Fetching results (117600)...
# Fetching results (117700)...
# Fetching results (117800)...
# Fetching results (117900)...
# Fetching results (118000)...
# Fetching results (118100)...
# Fetching results (118200)...
# Fetching results (118300)...
# Fetching results (118400)...
# Fetching results (118500)...
# Fetching results (118600)...
# Fetching results (118700)...
# Fetching results (118800)...
# Fetching results (118900)...
# Fetching results (119000)...
# Fetching results (119100)...
# Fetching results (119200)...
# Fetching results (119300)...
# Fetching results (119400)...
# Fetching results (119500)...
# Fetching results (119600)...
# Fetching results (119700)...
# Fetching results (119800)...
# Fetching results (119900)...
# Fetching results (120000)...
# Fetching results (120100)...
# Fetching results (120200)...
# Fetching results (120300)...
# Fetching results (120400)...
# Fetching results (120500)...
# Fetching results (120600)...
# Fetching results (120700)...
# Fetching results (120800)...
# Fetching results (120900)...
# Fetching results (121000)...
# Fetching results (121100)...
# Fetching results (121200)...
# Fetching results (121300)...
# Fetching results (121400)...
# Fetching results (121500)...
# Fetching results (121600)...
# Fetching results (121700)...
# Fetching results (121800)...
# Fetching results (121900)...
# Fetching results (122000)...
# Fetching results (122100)...
# Fetching results (122200)...
# Fetching results (122300)...
# Fetching results (122400)...
# Fetching results (122500)...
# Fetching results (122600)...
# Fetching results (122700)...
# Fetching results (122800)...
# Fetching results (122900)...
# Fetching results (123000)...
# Fetching results (123100)...
# Fetching results (123200)...
# Fetching results (123300)...
# Fetching results (123400)...
# Fetching results (123500)...
# Fetching results (123600)...
# Fetching results (123700)...
# Fetching results (123800)...
# Fetching results (123900)...
# Fetching results (124000)...
# Fetching results (124100)...
# Fetching results (124200)...
# Fetching results (124300)...
# Fetching results (124400)...
# Fetching results (124500)...
# Fetching results (124600)...
# Fetching results (124700)...
# Fetching results (124800)...
# Fetching results (124900)...
# Fetching results (125000)...
# Fetching results (125100)...
# Fetching results (125200)...
# Fetching results (125300)...
# Fetching results (125400)...
# Fetching results (125500)...
# Fetching results (125600)...
# Fetching results (125700)...
# Fetching results (125800)...
# Fetching results (125900)...
# Fetching results (126000)...
# Fetching results (126100)...
# Fetching results (126200)...
# Fetching results (126300)...
# Fetching results (126400)...
# Fetching results (126500)...
# Fetching results (126600)...
# Fetching results (126700)...
# Fetching results (126800)...
# Fetching results (126900)...
# Fetching results (127000)...
# Fetching results (127100)...
# Fetching results (127200)...
# Fetching results (127300)...
# Fetching results (127400)...
# Fetching results (127500)...
# Fetching results (127600)...
# Fetching results (127700)...
# Fetching results (127800)...
# Fetching results (127900)...
# Fetching results (128000)...
# Fetching results (128100)...
# Fetching results (128200)...
# Fetching results (128300)...
# Fetching results (128400)...
# Fetching results (128500)...
# Fetching results (128600)...
# Fetching results (128700)...
# Fetching results (128800)...
# Fetching results (128900)...
# Fetching results (129000)...
# Fetching results (129100)...
# Fetching results (129200)...
# Fetching results (129300)...
# Fetching results (129400)...
# Fetching results (129500)...
# Fetching results (129600)...
# Fetching results (129700)...
# Fetching results (129800)...
# Fetching results (129900)...
# Fetching results (130000)...
# Fetching results (130100)...
# Fetching results (130200)...
# Fetching results (130300)...
# Fetching results (130400)...
# Fetching results (130500)...
# Fetching results (130600)...
# Fetching results (130700)...
# Fetching results (130800)...
# Fetching results (130900)...
# Fetching results (131000)...
# Fetching results (131100)...
# Fetching results (131200)...
# Fetching results (131300)...
# Fetching results (131400)...
# Fetching results (131500)...
# Fetching results (131600)...
# Fetching results (131700)...
# Fetching results (131800)...
# Fetching results (131900)...
# Fetching results (132000)...
# Fetching results (132100)...
# Fetching results (132200)...
# Fetching results (132300)...
# Fetching results (132400)...
# Fetching results (132500)...
# Fetching results (132600)...
# Fetching results (132700)...
# Fetching results (132800)...
# Fetching results (132900)...
# Fetching results (133000)...
# Fetching results (133100)...
# Fetching results (133200)...
# Fetching results (133300)...
# Fetching results (133400)...
# Fetching results (133500)...
# Fetching results (133600)...
# Fetching results (133700)...
# Fetching results (133800)...
# Fetching results (133900)...
# Fetching results (134000)...
# Fetching results (134100)...
# Fetching results (134200)...
# Fetching results (134300)...
# Fetching results (134400)...
# Fetching results (134500)...
# Fetching results (134600)...
# Fetching results (134700)...
# Fetching results (134800)...
# Fetching results (134900)...
# Fetching results (135000)...
# Fetching results (135100)...
# Fetching results (135200)...
# Fetching results (135300)...
# Fetching results (135400)...
# Fetching results (135500)...
# Fetching results (135600)...
# Fetching results (135700)...
# Fetching results (135800)...
# Fetching results (135900)...
# Fetching results (136000)...
# Fetching results (136100)...
# Fetching results (136200)...
# Fetching results (136300)...
# Fetching results (136400)...
# Fetching results (136500)...
# Fetching results (136600)...
# Fetching results (136700)...
# Fetching results (136800)...
# Fetching results (136900)...
# Fetching results (137000)...
# Fetching results (137100)...
# Fetching results (137200)...
# Fetching results (137300)...
# Fetching results (137400)...
# Fetching results (137500)...
# Fetching results (137600)...
# Fetching results (137700)...
# Fetching results (137800)...
# Fetching results (137900)...
# Fetching results (138000)...
# Fetching results (138100)...
# Fetching results (138200)...
# Fetching results (138300)...
# Fetching results (138400)...
# Fetching results (138500)...
# Fetching results (138600)...
# Fetching results (138700)...
# Fetching results (138800)...
# Fetching results (138900)...
# Fetching results (139000)...
# Fetching results (139100)...
# Fetching results (139200)...
# Fetching results (139300)...
# Fetching results (139400)...
# Fetching results (139500)...
# Fetching results (139600)...
# Fetching results (139700)...
# Fetching results (139800)...
# Fetching results (139900)...
# Fetching results (140000)...
# Fetching results (140100)...
# Fetching results (140200)...
# Fetching results (140300)...
# Fetching results (140400)...
# Fetching results (140500)...
# Fetching results (140600)...
# Fetching results (140700)...
# Fetching results (140800)...
# Fetching results (140900)...
# Fetching results (141000)...
# Fetching results (141100)...
# Fetching results (141200)...
# Fetching results (141300)...
# Fetching results (141400)...
# Fetching results (141500)...
# Fetching results (141600)...
# Fetching results (141700)...
# Fetching results (141800)...
# Fetching results (141900)...
# Fetching results (142000)...
# Fetching results (142100)...
# Fetching results (142200)...
# Fetching results (142300)...
# Fetching results (142400)...
# Fetching results (142500)...
# Fetching results (142600)...
# Fetching results (142700)...
# Fetching results (142800)...
# Fetching results (142900)...
# Fetching results (143000)...
# Fetching results (143100)...
# Fetching results (143200)...
# Fetching results (143300)...
# Fetching results (143400)...
# Fetching results (143500)...
# Fetching results (143600)...
# Fetching results (143700)...
# Fetching results (143800)...
# Fetching results (143900)...
# Fetching results (144000)...
# Fetching results (144100)...
# Fetching results (144200)...
# Fetching results (144300)...
# Fetching results (144400)...
# Fetching results (144500)...
# Fetching results (144600)...
# Fetching results (144700)...
# Fetching results (144800)...
# Fetching results (144900)...
# Fetching results (145000)...
# Fetching results (145100)...
# Fetching results (145200)...
# Fetching results (145300)...
# Fetching results (145400)...
# Fetching results (145500)...
# Fetching results (145600)...
# Fetching results (145700)...
# Fetching results (145800)...
# Fetching results (145900)...
# Fetching results (146000)...
# Fetching results (146100)...
# Fetching results (146200)...
# Fetching results (146300)...
# Fetching results (146400)...
# Fetching results (146500)...
# Fetching results (146600)...
# Fetching results (146700)...
# Fetching results (146800)...
# Fetching results (146900)...
# Fetching results (147000)...
# Fetching results (147100)...
# Fetching results (147200)...
# Fetching results (147300)...
# Fetching results (147400)...
# Fetching results (147500)...
# Fetching results (147600)...
# Fetching results (147700)...
# Fetching results (147800)...
# Fetching results (147900)...
# Fetching results (148000)...
# Fetching results (148100)...
# Fetching results (148200)...
# Fetching results (148300)...
# Fetching results (148400)...
# Fetching results (148500)...
# Fetching results (148600)...
# Fetching results (148700)...
# Fetching results (148800)...
# Fetching results (148900)...
# Fetching results (149000)...
# Fetching results (149100)...
# Fetching results (149200)...
# Fetching results (149300)...
# Fetching results (149400)...
# Fetching results (149500)...
# Fetching results (149600)...
# Fetching results (149700)...
# Fetching results (149800)...
# Fetching results (149900)...
# Fetching results (150000)...
# Fetching results (150100)...
# Fetching results (150200)...
# Fetching results (150300)...
# Fetching results (150400)...
# Fetching results (150500)...
# Fetching results (150600)...
# Fetching results (150700)...
# Fetching results (150800)...
# Fetching results (150900)...
# Fetching results (151000)...
# Fetching results (151100)...
# Fetching results (151200)...
# Fetching results (151300)...
# Fetching results (151400)...
# Fetching results (151500)...
# Fetching results (151600)...
# Fetching results (151700)...
# Fetching results (151800)...
# Fetching results (151900)...
# Fetching results (152000)...
# Fetching results (152100)...
# Fetching results (152200)...
# Fetching results (152300)...
# Fetching results (152400)...
# Fetching results (152500)...
# Fetching results (152600)...
# Fetching results (152700)...
# Fetching results (152800)...
# Fetching results (152900)...
# Fetching results (153000)...
# Fetching results (153100)...
# Fetching results (153200)...
# Fetching results (153300)...
# Fetching results (153400)...
# Fetching results (153500)...
# Fetching results (153600)...
# Fetching results (153700)...
# Fetching results (153800)...
# Fetching results (153900)...
# Fetching results (154000)...
# Fetching results (154100)...
# Fetching results (154200)...
# Fetching results (154300)...
# Fetching results (154400)...
# Fetching results (154500)...
# Fetching results (154600)...
# Fetching results (154700)...
# Fetching results (154800)...
# Fetching results (154900)...
# Fetching results (155000)...
# Fetching results (155100)...
# Fetching results (155200)...
# Fetching results (155300)...
# Fetching results (155400)...
# Fetching results (155500)...
# Fetching results (155600)...
# Fetching results (155700)...
# Fetching results (155800)...
# Fetching results (155900)...
# Fetching results (156000)...
# Fetching results (156100)...
# Fetching results (156200)...
# Fetching results (156300)...
# Fetching results (156400)...
# Fetching results (156500)...
# Fetching results (156600)...
# Fetching results (156700)...
# Fetching results (156800)...
# Fetching results (156900)...
# Fetching results (157000)...
# Fetching results (157100)...
# Fetching results (157200)...
# Fetching results (157300)...
# Fetching results (157400)...
# Fetching results (157500)...
# Fetching results (157600)...
# Fetching results (157700)...
# Fetching results (157800)...
# Fetching results (157900)...
# Fetching results (158000)...
# Fetching results (158100)...
# Fetching results (158200)...
# Fetching results (158300)...
# Fetching results (158400)...
# Fetching results (158500)...
# Fetching results (158600)...
# Fetching results (158700)...
# Fetching results (158800)...
# Fetching results (158900)...
# Fetching results (159000)...
# Fetching results (159100)...
# Fetching results (159200)...
# Fetching results (159300)...
# Fetching results (159400)...
# Fetching results (159500)...
# Fetching results (159600)...
# Fetching results (159700)...
# Fetching results (159800)...
# Fetching results (159900)...
# Fetching results (160000)...
# Fetching results (160100)...
# Fetching results (160200)...
# Fetching results (160300)...
# Fetching results (160400)...
# Fetching results (160500)...
# Fetching results (160600)...
# Fetching results (160700)...
# Fetching results (160800)...
# Fetching results (160900)...
# Fetching results (161000)...
# Fetching results (161100)...
# Fetching results (161200)...
# Fetching results (161300)...
# Fetching results (161400)...
# Fetching results (161500)...
# Fetching results (161600)...
# Fetching results (161700)...
# Fetching results (161800)...
# Fetching results (161900)...
# Fetching results (162000)...
# Fetching results (162100)...
# Fetching results (162200)...
# Fetching results (162300)...
# Fetching results (162400)...
# Fetching results (162500)...
# Fetching results (162600)...
# Fetching results (162700)...
# Fetching results (162800)...
# Fetching results (162900)...
# Fetching results (163000)...
# Fetching results (163100)...
# Fetching results (163200)...
# Fetching results (163300)...
# Fetching results (163400)...
# Fetching results (163500)...
# Fetching results (163600)...
# Fetching results (163700)...
# Fetching results (163800)...
# Fetching results (163900)...
# Fetching results (164000)...
# Fetching results (164100)...
# Fetching results (164200)...
# Fetching results (164300)...
# Fetching results (164400)...
# Fetching results (164500)...
# Fetching results (164600)...
# Fetching results (164700)...
# Fetching results (164800)...
# Fetching results (164900)...
# Fetching results (165000)...
# Fetching results (165100)...
# Fetching results (165200)...
# Fetching results (165300)...
# Fetching results (165400)...
# Fetching results (165500)...
# Fetching results (165600)...
# Fetching results (165700)...
# Fetching results (165800)...
# Fetching results (165900)...
# Fetching results (166000)...
# Fetching results (166100)...
# Fetching results (166200)...
# Fetching results (166300)...
# Fetching results (166400)...
# Fetching results (166500)...
# Fetching results (166600)...
# Fetching results (166700)...
# Fetching results (166800)...
# Fetching results (166900)...
# Fetching results (167000)...
# Fetching results (167100)...
# Fetching results (167200)...
# Fetching results (167300)...
# Fetching results (167400)...
# Fetching results (167500)...
# Fetching results (167600)...
# Fetching results (167700)...
# Fetching results (167800)...
# Fetching results (167900)...
# Fetching results (168000)...
# Fetching results (168100)...
# Fetching results (168200)...
# Fetching results (168300)...
# Fetching results (168400)...
# Fetching results (168500)...
# Fetching results (168600)...
# Fetching results (168700)...
# Fetching results (168800)...
# Fetching results (168900)...
# Fetching results (169000)...
# Fetching results (169100)...
# Fetching results (169200)...
# Fetching results (169300)...
# Fetching results (169400)...
# Fetching results (169500)...
# Fetching results (169600)...
# Fetching results (169700)...
# Fetching results (169800)...
# Fetching results (169900)...
# Fetching results (170000)...
# Fetching results (170100)...
# Fetching results (170200)...
# Fetching results (170300)...
# Fetching results (170400)...
# Fetching results (170500)...
# Fetching results (170600)...
# Fetching results (170700)...
# Fetching results (170800)...
# Fetching results (170900)...
# Fetching results (171000)...
# Fetching results (171100)...
# Fetching results (171200)...
# Fetching results (171300)...
# Fetching results (171400)...
# Fetching results (171500)...
# Fetching results (171600)...
# Fetching results (171700)...
# Fetching results (171800)...
# Fetching results (171900)...
# Fetching results (172000)...
# Fetching results (172100)...
# Fetching results (172200)...
# Fetching results (172300)...
# Fetching results (172400)...
# Fetching results (172500)...
# Fetching results (172600)...
# Fetching results (172700)...
# Fetching results (172800)...
# Fetching results (172900)...
# Fetching results (173000)...
# Fetching results (173100)...
# Fetching results (173200)...
# Fetching results (173300)...
# Fetching results (173400)...
# Fetching results (173500)...
# Fetching results (173600)...
# Fetching results (173700)...
# Fetching results (173800)...
# Fetching results (173900)...
# Fetching results (174000)...
# Fetching results (174100)...
# Fetching results (174200)...
# Fetching results (174300)...
# Fetching results (174400)...
# Fetching results (174500)...
# Fetching results (174600)...
# Fetching results (174700)...
# Fetching results (174800)...
# Fetching results (174900)...
# Fetching results (175000)...
# Fetching results (175100)...
# Fetching results (175200)...
# Fetching results (175300)...
# Fetching results (175400)...
# Fetching results (175500)...
# Fetching results (175600)...
# Fetching results (175700)...
# Fetching results (175800)...
# Fetching results (175900)...
# Fetching results (176000)...
# Fetching results (176100)...
# Fetching results (176200)...
# Fetching results (176300)...
# Fetching results (176400)...
# Fetching results (176500)...
# Fetching results (176600)...
# Fetching results (176700)...
# Fetching results (176800)...
# Fetching results (176900)...
# Fetching results (177000)...
# Fetching results (177100)...
# Fetching results (177200)...
# Fetching results (177300)...
# Fetching results (177400)...
# Fetching results (177500)...
# Fetching results (177600)...
# Fetching results (177700)...
# Fetching results (177800)...
# Fetching results (177900)...
# Fetching results (178000)...
# Fetching results (178100)...
# Fetching results (178200)...
# Fetching results (178300)...
# Fetching results (178400)...
# Fetching results (178500)...
# Fetching results (178600)...
# Fetching results (178700)...
# Fetching results (178800)...
# Fetching results (178900)...
# Fetching results (179000)...
# Fetching results (179100)...
# Fetching results (179200)...
# Fetching results (179300)...
# Fetching results (179400)...
# Fetching results (179500)...
# Fetching results (179600)...
# Fetching results (179700)...
# Fetching results (179800)...
# Fetching results (179900)...
# Fetching results (180000)...
# Fetching results (180100)...
# Fetching results (180200)...
# Fetching results (180300)...
# Fetching results (180400)...
# Fetching results (180500)...
# Fetching results (180600)...
# Fetching results (180700)...
# Fetching results (180800)...
# Fetching results (180900)...
# Fetching results (181000)...
# Fetching results (181100)...
# Fetching results (181200)...
# Fetching results (181300)...
# Fetching results (181400)...
# Fetching results (181500)...
# Fetching results (181600)...
# Fetching results (181700)...
# Fetching results (181800)...
# Fetching results (181900)...
# Fetching results (182000)...
# Fetching results (182100)...
# Fetching results (182200)...
# Fetching results (182300)...
# Fetching results (182400)...
# Fetching results (182500)...
# Fetching results (182600)...
# Fetching results (182700)...
# Fetching results (182800)...
# Fetching results (182900)...
# Fetching results (183000)...
# Fetching results (183100)...
# Fetching results (183200)...
# Fetching results (183300)...
# Fetching results (183400)...
# Fetching results (183500)...
# Fetching results (183600)...
# Fetching results (183700)...
# Fetching results (183800)...
# Fetching results (183900)...
# Fetching results (184000)...
# Fetching results (184100)...
# Fetching results (184200)...
# Fetching results (184300)...
# Fetching results (184400)...
# Fetching results (184500)...

# %%
# Save raw search results 
output_file_path = os.path.join(output_dir, 'searchresults.csv')
df = pd.DataFrame(papers)
df.to_csv(output_file_path, index=False)
print(f'Done. Fetched {len(df)} papers. File saved to {output_file_path}')
# Out:
# Done. Fetched 182747 papers. File saved to ./output/searchresults.csv

# %%
# Clean the search results data
print("Before cleaning step 1: ",len(df))

#df = df[df['Authors'].notna() & (df['Authors'] != '')].reset_index(drop=True)
#df = df[ ~df['PaperTitle'].str.lower().str.startswith((
#        'supplem', 'data from', 'data to', 'datasheet', 'dataset', 
#        'supporting figure', 'supp fig', 'supp table', 'supp.', 'suppl.', 'suppl data', 'suppl fig',
#        'data supplement', 'fig.', 'figure'
#    ))].reset_index(drop=True)
#df = df[ df['Abstract'].str.len() < 32000 ].reset_index(drop=True)  
#df = df.drop_duplicates(subset=['PaperTitle', 'Authors', 'PubDate'])


# Define cleaning steps and initialize tqdm progress bar
cleaning_steps = [
    "Removing missing/empty PaperId",
    "Removing duplicate PaperId entries",
    "Removing duplicate entries with identical PaperTitle & Authors",
    "Removing missing/empty PaperTitle",
    "Removing missing/empty Abstract",
    "Removing missing/empty PubDate",
    "Validating PubDate format (YYYY-MM-DD)",
    "Removing missing/empty Authors"
]
progress_bar = tqdm(total=len(cleaning_steps), desc="Cleaning Data", unit="step")

# Count initial number of rows
initial_article_count = len(df)

# Removing missing/empty PaperId
missing_paperid_count = df['PaperId'].isna().sum()
empty_paperid_count = (df['PaperId'].astype(str).str.strip() == "").sum()
df = df.dropna(subset=['PaperId'])
df = df[df['PaperId'].astype(str).str.strip() != ""]
progress_bar.update(1)

# Removing missing/empty PaperTitle
missing_title_count = df['PaperTitle'].isna().sum()
empty_title_count = (df['PaperTitle'].str.strip() == "").sum()
df = df.dropna(subset=['PaperTitle'])
df = df[df['PaperTitle'].str.strip() != ""]
progress_bar.update(1)

# Removing missing/empty Abstract
missing_abstract_count = df['Abstract'].isna().sum()
empty_abstract_count = (df['Abstract'].str.strip() == "").sum()
df = df.dropna(subset=['Abstract'])
df = df[df['Abstract'].str.strip() != ""]
progress_bar.update(1)

# Removing missing/empty Authors
missing_authors_count = df['Authors'].isna().sum()
empty_authors_count = (df['Authors'].astype(str).str.strip() == "").sum()
df = df.dropna(subset=['Authors'])
df = df[df['Authors'].astype(str).str.strip() != ""]
progress_bar.update(1)

# Removing missing/empty PubDate
missing_pubdate_count = df['PubDate'].isna().sum()
empty_pubdate_count = (df['PubDate'].astype(str).str.strip() == "").sum()
df = df.dropna(subset=['PubDate'])
df = df[df['PubDate'].astype(str).str.strip() != ""]
progress_bar.update(1)

# Validate PubDate format (YYYY-MM-DD)
def is_valid_date(date_str):
    return bool(re.match(r'^\d{4}-\d{2}-\d{2}$', str(date_str)))
invalid_pubdate_count = df[~df['PubDate'].astype(str).apply(is_valid_date)].shape[0]
df = df[df['PubDate'].astype(str).apply(is_valid_date)]
progress_bar.update(1)

# Removing duplicate PaperId entries
duplicate_paperid_count = df.duplicated(subset=['PaperId']).sum()
df = df.drop_duplicates(subset=['PaperId'], keep='first')
progress_bar.update(1)

# Removing duplicate entries with identical PaperTitle & Authors
df["_temp_PaperTitle"] = df["PaperTitle"].str.lower()
df["_temp_Authors"] = df["Authors"].str.lower()
duplicate_entries_count = df.duplicated(subset=["_temp_PaperTitle", "_temp_Authors"]).sum()
df = df.drop_duplicates(subset=["_temp_PaperTitle", "_temp_Authors"], keep="first")
df.drop(columns=["_temp_PaperTitle", "_temp_Authors"], inplace=True)
progress_bar.update(1)  


# Close the progress bar
progress_bar.close()

# Count final number of rows after all removals
article_count_after_duplicates_and_missings = len(df)
total_removed = initial_article_count - article_count_after_duplicates_and_missings

# Sum the duplicate removals
total_duplicates_removed = duplicate_paperid_count + duplicate_entries_count

# Sum the missing removals
missing_values = (
    missing_paperid_count + empty_paperid_count +
    missing_title_count + empty_title_count +
    missing_abstract_count + empty_abstract_count +
    missing_pubdate_count + empty_pubdate_count + invalid_pubdate_count +
    missing_authors_count + empty_authors_count
)

# Collect removal statistics
removal_log = [
    f"Initial number of articles: {initial_article_count:,}",
    f"\n-Removed due to missing PaperId (NaN): {missing_paperid_count:,}",
    f"-Removed due to empty PaperId (''): {empty_paperid_count:,}", 
    f"-Removed due to missing PaperTitle (NaN): {missing_title_count:,}",
    f"-Removed due to empty PaperTitle (''): {empty_title_count:,}",
    f"-Removed due to missing Abstract (NaN): {missing_abstract_count:,}",
    f"-Removed due to empty Abstract (''): {empty_abstract_count:,}",
    f"-Removed due to missing PubDate (NaN): {missing_pubdate_count:,}",
    f"-Removed due to empty PubDate (''): {empty_pubdate_count:,}",
    f"-Removed due to invalid PubDate format (not YYYY-MM-DD): {invalid_pubdate_count:,}",
    f"-Removed due to missing Authors (NaN): {missing_authors_count:,}",
    f"-Removed due to empty Authors (''): {empty_authors_count:,}",
    f"-Removed due to duplicate PaperId entries: {duplicate_paperid_count:,}",
    f"-Removed due to duplicate entries with identical PaperTitle & Authors: {duplicate_entries_count:,}", 
    
    f"\nTotal articles with missing data removed: {missing_values:,}", 
    f"Total duplicate entries removed: {total_duplicates_removed:,}", 
    f"Total articles removed: {total_removed:,}",
    
    f"\nFinal number of articles after cleaning steps: {article_count_after_duplicates_and_missings:,}"
]

# Print removal details
print("\n".join(removal_log))

output_file_path = os.path.join(output_dir, 'searchresults-cleaned.csv')
df.to_csv(output_file_path, index=False)

print(f'File saved to {output_file_path}')
# Out:
# Before cleaning step 1:  182747
# Cleaning Data: 100%|████████████████████████████████████████████████████████████████████████████████| 8/8 [00:02<00:00,  3.04step/s]
# Initial number of articles: 182,747
#
# -Removed due to missing PaperId (NaN): 0
# -Removed due to empty PaperId (''): 0
# -Removed due to missing PaperTitle (NaN): 0
# -Removed due to empty PaperTitle (''): 1
# -Removed due to missing Abstract (NaN): 0
# -Removed due to empty Abstract (''): 0
# -Removed due to missing PubDate (NaN): 0
# -Removed due to empty PubDate (''): 0
# -Removed due to invalid PubDate format (not YYYY-MM-DD): 0
# -Removed due to missing Authors (NaN): 0
# -Removed due to empty Authors (''): 2,279
# -Removed due to duplicate PaperId entries: 0
# -Removed due to duplicate entries with identical PaperTitle & Authors: 3,750
#
# Total articles with missing data removed: 2,280
# Total duplicate entries removed: 3,750
# Total articles removed: 6,030
#
# Final number of articles after cleaning steps: 176,717
# File saved to ./output/searchresults-cleaned.csv

# %%
# Cleaning step 2 

# Progress bar
tqdm.pandas()

# Ensure consistent language detection (fixes randomness)
DetectorFactory.seed = 0  

# Start tracking runtime
start_time = time.time()

# Function to detect language separately for PaperTitle and Abstract with retry logic
def detect_language(row):
    try:
        title = str(row['PaperTitle']).strip().lower() if pd.notna(row['PaperTitle']) else ""
        abstract = str(row['Abstract']).strip() if pd.notna(row['Abstract']) else ""

        # Apply language detection with retry mechanism
        def safe_detect(text, max_retries=3):
            for _ in range(max_retries):
                try:
                    return detect(text) if len(text) > 10 else "unknown"  # Ignore very short text
                except:
                    pass
            return "error"  # If all retries fail, mark as error

        title_lang = safe_detect(title)
        abstract_lang = safe_detect(abstract)

        # Keep if AT LEAST ONE is English
        return "en" if title_lang == "en" or abstract_lang == "en" else "non-en"

    except Exception:
        return "error"  # Suppresses error messages

# Apply language detection with progress bar on the full dataset
df["detected_language"] = df.progress_apply(detect_language, axis=1)

# Separate English and non-English articles (Keep if AT LEAST ONE column is English)
df_filtered_cleaned = df[df["detected_language"] == "en"].drop(columns=["detected_language"])
df_dropped = df[df["detected_language"] != "en"]

# Store lengths in variables
total_rows_before = len(df)
dropped_rows = len(df_dropped)
total_rows_after = len(df_filtered_cleaned)

# Stop tracking runtime
end_time = time.time()
runtime_seconds = end_time - start_time
runtime_minutes = runtime_seconds / 60  # Convert seconds to minutes

# Save results
df_dropped.to_csv(os.path.join(output_dir, "searchresults_non_english.csv"), index=False)
df_filtered_cleaned.to_csv(os.path.join(output_dir, "searchresults-cleaned.csv"), index=False)

# Final print statement
print(f"Language filtering complete. Non-English articles removed: {dropped_rows:,}.")
print(f"Total time: {runtime_seconds:.2f} seconds ({runtime_minutes:.2f} minutes).")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 176717/176717 [21:14<00:00, 138.69it/s]
# Language filtering complete. Non-English articles removed: 583.
# Total time: 1274.26 seconds (21.24 minutes).

# %%
# Start tracking runtime
tqdm.pandas()
start_time = time.time()

# Keywords to match at the start of the PaperTitle column (sorted, formatted)
all_keywords = sorted([
    "Acknowledgments", "ADOBE PDF", "Addendum", "Advertisement", "Additional figure", "Additional Material", 
    "Additional Table", "All Supplemental Data", "All Supplemental Figures", 
    "All Supplemental Figures, Tables and Legends", "All Supplementary Data", 
    "All Supplementary Figures", "All Supplementary Figures and Tables", 
    "All Supplementary Tables, Figures and Methods", "Analysis Methods Supplement", 
    "Appendix", "Article figures", "Author Correction", "Auxiliary Supplementary File", 
    "Caption for Suppl Fig.", "Captions of supplementary", "Combined supplemental figures", 
    "Contents Vol", "Contents:",
    "Corrigendum", "Correction", "Correction to", "Correction:", "Corrections to", 
    "Data Augmentation", "Data associated with", "Data and code", "Data and analysis scripts", "Data File", 
    "Data for", "Data from", "Data not shown", "Data and metadata",
    "Data on", "Data S", "Data Spreadsheet", "Data Supplement", "Data.zip", 
    "Dataset", "Dataset and metadata", "Dataset for", "Dataset related to", 
    "Description of Supplemental Figures", "Description of supplementary", 
    "Download Supplementary", "eFigure", "Erratum", "Extended Data", "Expression of Concern",
    "Fig", "Fig.", "Fig Supp", "FigS", "Figure", "Figure S", "Figures", "Instructions for Authors",
    "File", "Funding statement", "http://", "https://", 
    "Legend for", "Legend from", "Legend of", "Legend to", 
    "Legends for", "Legends from", "Legends of", "Legends to", 
    "Legends Supplemental Figures", "Link to Supplementary", 
    "List of figures", "List of tables", "List of plates", "Manuscript Figures", 
    "Mat & Met", "Material and Methods", "Materials and Methods", 
    "Merged Supplementary", "Metadata and data", "Metadata record for", 
    "Metadata supporting", "Methods References", "Methods and Materials from", 
    "Methods and Supplementary", "Methods and Tables", "Methods file", 
    "Methods from", "Methods, Figures", "Methods, Table", "MET supplementary methods", 
    "methods_", "Movie", "Multimedia", "Methodology and Method", "Online supplement", 
    "Online Supplementary Materials", "Online Supplementary Tables", 
    "Online-only supplementary", "Online-Only Tables", 
    "Original Western Blot Data", "Revised Supplementary", "S Figure", "S Table", 
    "S-Figure", "S1 Legend", "S1 from", "S1.", "S1:", "S2 from", "S2.", "S2:", 
    "S3 from", "S3.", "S3:", "S4 from", "S4.", "S4:", "S5 from", "S5.", "S5:", 
    "S6 from", "S6.", "S6:", "S7 from", "S7.", "S7:", "S8 from", "S8.", "S8:", 
    "S9 from", "S9.", "S9:", "SI Figure", "SI Methods", "SI Table", 
    "SI materials", "SI tables and figures", "SFigure", "SF-", "SF1", 
    "Sl Figure", "Supplement", "Supplement Material", "Supplement Table", 
    "Supplemental", "Supplemental Data", "Supplemental Figure", 
    "Supplemental Figures", "Supplemental Table", "Supplementary", 
    "Supplementary Data", "Supplementary Figure", "Supplementary Figures", 
    "Supplementary Legends", "Supplementary Methods", "Supplementary Movie", 
    "Supplementary Table", "Supplementary Tables", "Supplementary Text", 
    "Supplementary Video", "SupplementaryFigures", "Supplementary_Figure", 
    "Supplementray Figures", "Supplementray Tables", "Supplymentary Figure", 
    "Supplymentary Figures", "Supplymentary Table", "Supporting Data", 
    "Supporting Document", "Supporting Figure", "Supporting Figures", 
    "Supporting File", "Supporting Information", "Supporting Legend", 
    "Supporting Legends", "Supporting Materials", "Supporting Methods", 
    "Supporting Table", "Supporting Tables", "Supporting Text", 
    "Supporting Video", "Suppl", "Suppl Figure", "Suppl Figures", "Suppl File", 
    "Suppl Info", "Suppl Information", "Suppl Legends", "Suppl List of Videos, Tables and Methods", 
    "Suppl Materials and Methods", "Suppl Methods", "Suppl Movie", "Suppl Table", 
    "Suppl Video", "Supplimentary Figure", "Supplimentary Methods", 
    "Supplimentary Tables", "Supplimentary_Figure", "Suplementary", "Supllementary Figure", 
    "Suplplementary Figure Legend", "Suplpementary Table", "Supplrmentary Figures", 
    "Supplrmentary Tables", "Suppltable", "Suppltext", "Supplvideo", 
    "Suppl_Figure", "Suppl-Figure", "Suupplementary Tables", "Table", "Table of Content",
    "Validation Figures", "Video", "Western Blots from", "Whole Slide Image"
])

# Keywords to match anywhere in the PaperTitle column (sorted, formatted)
middle_keywords = sorted([
    "Combined Supplementary Materials", "Corrigendum", "The Case Files", "Additional file",
    "Figure S", "Figures S", "Manuscript Figures", "SI tables and figures", 
    "Supplemental Data", "Supplemental figures", "Supplemental from", 
    "Supplemental table", "Supplemental figure", "Supplementary Figure", 
    "Supplementary Figures", "Supplementary Material", "Supplementary Methods", 
    "Supplementary Table", "Supplementary Tables", "Supplementary data", 
    "Supplementary document", "Supplementary information", "SupplementaryFigures", 
    "Supplementary materials and methods", 
    "Translation for the Article", "Video Dataset", "Operative Video"
])


# Compile regex patterns for faster execution
start_pattern = re.compile(r"^(?:" + "|".join(map(re.escape, all_keywords)) + r")", re.IGNORECASE)
middle_pattern = re.compile(r"\b(?:{})\b".format("|".join(map(re.escape, middle_keywords))), re.IGNORECASE)
supplementary_pattern = re.compile(r"[\w\-_]*supple\w*", re.IGNORECASE)

# Count initial rows
rows_before_artifacts = len(df_filtered_cleaned)

# Apply filtering with a progress bar
tqdm.pandas(desc="Filtering Data")

df_filtered_cleaned = df_filtered_cleaned[
    ~df_filtered_cleaned["PaperTitle"].progress_apply(lambda title: bool(start_pattern.match(str(title)))) &
    ~df_filtered_cleaned["PaperTitle"].progress_apply(lambda title: bool(middle_pattern.search(str(title)))) &
    ~df_filtered_cleaned["PaperTitle"].progress_apply(lambda title: "_" in str(title)) &
    ~df_filtered_cleaned["PaperTitle"].progress_apply(lambda title: bool(supplementary_pattern.search(str(title))))
]

# Count remaining and removed rows
final_row_count = len(df_filtered_cleaned)
artifacts_removed = rows_before_artifacts - final_row_count

# Display results
print(f"\nInitial number of rows before artifact removal: {rows_before_artifacts:,}")
print(f"Number of rows identified as artifacts and removed: {artifacts_removed:,}")
print(f"Final number of rows in the cleaned dataset: {final_row_count:,}")

# Save the cleaned dataset
df_filtered_cleaned.to_csv(os.path.join(output_dir, "searchresults-cleaned.csv"), index=False)

# End tracking runtime
end_time = time.time()
print(f"Processing completed in {end_time - start_time:.2f} seconds.")
# Out:
# Filtering Data: 100%|███████████████████████████████████████████████████████████████████| 176134/176134 [00:00<00:00, 303130.58it/s]
# Filtering Data: 100%|████████████████████████████████████████████████████████████████████| 176134/176134 [00:02<00:00, 83824.43it/s]
# Filtering Data: 100%|██████████████████████████████████████████████████████████████████| 176134/176134 [00:00<00:00, 1412950.09it/s]
# Filtering Data: 100%|████████████████████████████████████████████████████████████████████| 176134/176134 [00:02<00:00, 68763.17it/s]
# Initial number of rows before artifact removal: 176,134
# Number of rows identified as artifacts and removed: 791
# Final number of rows in the cleaned dataset: 175,343
# Processing completed in 18.43 seconds.

# %%
# Initialize removal counts
nonsense_title_counts = 0
title_length_counts = 0
abstract_length_counts = 0
withdraw_counts = 0
non_research_counts = 0

# Define cleaning steps for progress bar
new_cleaning_steps = [
    "Removing numeric/nonsense titles",
    "Removing placeholder titles",
    "Filtering by title length",
    "Filtering by abstract length",
    "Removing withdrawn/withdrawal articles",
    "Removing non-research articles (Editorials, News, etc.)"
]

progress_bar = tqdm(total=len(new_cleaning_steps), desc="Additional Cleaning", unit="step")

# ========== Removing numeric/nonsense titles ==========
pattern_numeric = re.compile(r'^[^A-Za-z]+$')  # Matches titles with no letters (only numbers/symbols)
mask_numeric = df_filtered_cleaned["PaperTitle"].apply(lambda title: bool(pattern_numeric.match(str(title))))
nonsense_title_counts += mask_numeric.sum()
df_filtered_cleaned = df_filtered_cleaned[~mask_numeric]
progress_bar.update(1)
print(f"Identified numeric/nonsense titles: {mask_numeric.sum():,}")

# ========== Removing placeholder titles ==========
placeholders = {
    "Title Not Available", "No Title", "Untitled", "N/A",
    "[No title available]", "No title available", "No title available - PubMed",
    "Error in Text", "Errors in Box", "Error in Author Name", "Error in Author Names",
    "Error in Author Surnames", "Errors in article text", "Error in Figure Label and Caption",
    "Error in Presentation of Author", "Errors in Author Name", "Error in Author Name",
    "Error in Table Text","Error in Corresponding Authorship",
}

placeholder_pattern = re.compile(
    r"\b(?:{})\b".format("|".join(map(re.escape, placeholders))), re.IGNORECASE
)
mask_placeholders = df_filtered_cleaned["PaperTitle"].apply(lambda title: bool(placeholder_pattern.search(str(title))))
print(f"Identified placeholders: {mask_placeholders.sum():,}")
nonsense_title_counts += mask_placeholders.sum()
df_filtered_cleaned = df_filtered_cleaned[~mask_placeholders]
progress_bar.update(1)

# ========== Filtering by title length ==========
def count_real_words(text):
    words = re.findall(r'\b[a-zA-Z]{2,}\b', str(text))  # Only words with 2+ letters
    return len(words)

def valid_title_length(title, min_words=3, max_words=60):
    return min_words <= count_real_words(title) <= max_words

df_filtered_cleaned = df_filtered_cleaned.reset_index(drop=True)
mask_valid_title = df_filtered_cleaned["PaperTitle"].apply(valid_title_length)

title_length_counts = (~mask_valid_title).sum()
print(f"Invalid PaperTitle count (too short/long): {title_length_counts:,}")

# Remove invalid titles first
df_filtered_cleaned = df_filtered_cleaned[mask_valid_title]
progress_bar.update(1)

# ========== Filtering by abstract length ==========
def valid_abstract_length(abstract, min_words=80, max_words=1000):
    return min_words <= count_real_words(abstract) <= max_words

mask_valid_abstract = df_filtered_cleaned["Abstract"].apply(valid_abstract_length)
abstract_length_counts = (~mask_valid_abstract).sum()

print(f"Invalid Abstract count (too short/long): {abstract_length_counts:,}")

# Remove invalid abstracts (after title filtering)
df_filtered_cleaned = df_filtered_cleaned[mask_valid_abstract]
progress_bar.update(1)

# ========== Removing withdrawn/retracted papers ==========
withdrawn_retraction_pattern = re.compile(
    r"(?i)^(?:\[?)?(Withdrawn|Withdrawal|Retracted|Retraction|Errata|Erratum|Revoked|Removed|Correction Notice|Corrigendum)\b"
)
mask_withdrawn = df_filtered_cleaned["PaperTitle"].apply(lambda title: bool(withdrawn_retraction_pattern.search(str(title))))
withdraw_counts = mask_withdrawn.sum()
df_filtered_cleaned = df_filtered_cleaned[~mask_withdrawn]
progress_bar.update(1)
print(f"Identified withdrawn: {withdraw_counts:,}")


# ========== Removing non-research articles ==========
non_research_keywords = [
    "A reply to Letter to the editor", "About the Author", "An Update from the Editor-in-Chief",
    "Announcement:", "Announcements", "Appeal", "ASO Author Reflection", "AUTHOR COPY ONLY", 
    "Associate Editor", "Author comment:", "Author profile", "Author Reflections:", "Author reply", 
    "Author response", "Author response to", "Author view", "Author's reply", "Author's respond", 
    "Editor's Reflection", "Editors Reflection", "Editors' Reflection", "Editor' Reflection",
    "Author's response", "Author's view", "Authors reply", "Authors respond", "Authors response", 
    "Authors view", "Authors' Reply", "Authors' response", "Authors's response", "Book Review", "EditorinChief",
    "Comment", "Comment on", "Commentary", "Conference Summary", "Conversation with the Editor", 
    "Correspondence", "Editorial", "Editor Profile", "Editor response for", "Editor change", "New Editor",
    "Editor-in-Chief", "Editorinchief's introduction", "Editor's evaluation", "Editor's Introduction", 
    "Editor's Message", "Editor's note", "Editors Introduction", "Editors Message", "Editors Note on", 
    "Editors Spotlight", "Editors change", "Editors note", "Editors' Introduction", "Editors' Message", 
    "Editors' note", "Foreword", "From the Editor", "From the Editor-in-Chief", "From the Editors...", 
    "From the Editors Desk...", "From the Editor's desk", "From the editors desk", "From the Guest Editor", "Guest editor",
    "Guest editorial", "Introducing our new Editors", "Issue Editor Foreword", "Issue Information Editorial Board", 
    "Letter to editor", "Letter to the Editor", "Letter:", "Letter Of The Editor", "Letters of the editor", "Letter-to-the-editor", 
    "Letters to editor", "Letters to the editor", "Meet the First Author", "Meet the author", "Meet the editor", 
    "Message from Editor", "Message from the Editor", "News", "Opinion", "our author", "our editor", 
    "Reply:", "In reply:", "Reply to:", "In reply to:",
    "Perspective", "Preface", "Proceedings", "Publisher'?s? Note", "Reply by Author", "Reply by the author", 
    "Reply to Editorial Comment", "Reply to Letter to", "Reply to correspondence", "Reply to the Letter to", 
    "Response to Editorial", "Response to a letter", "Response to letter", "senior editor", "Special Section", 
    "The Author Reply", "The Authors Reply", "To the Editor", "Transitioning Between Editor", "Viewpoint", 
    "Welcome to our", "Executive Editor","Assistant Editor",
]


# Convert keywords into a single regex pattern (match anywhere in the title)
escaped_keywords = [re.escape(keyword) for keyword in non_research_keywords]
non_research_pattern = "|".join(escaped_keywords)  # No caret (^) to match anywhere

df_filtered_cleaned["PaperTitle"] = df_filtered_cleaned["PaperTitle"].fillna("").str.strip().str.replace(r"\s+", " ", regex=True)
mask_non_research = df_filtered_cleaned["PaperTitle"].str.contains(non_research_pattern, case=False, na=False)
non_research_counts = mask_non_research.sum()
df_filtered_cleaned = df_filtered_cleaned[~mask_non_research]
progress_bar.update(1)
print(f"Identified non-research articles: {non_research_counts:,}")

progress_bar.close()

# ========== Compute final counts ==========
# Calculate total removed
total_removed = (
    nonsense_title_counts
    + title_length_counts
    + abstract_length_counts
    + withdraw_counts
    + non_research_counts
)

final_article_count = len(df_filtered_cleaned)

# ========== Final summary & consistency check ==========
removal_log = [
    f"Removed numeric/nonsense titles & placeholders: {nonsense_title_counts:,}",
    f"Removed due to title length issues: {title_length_counts:,}",
    f"Removed due to abstract length issues: {abstract_length_counts:,}",
    f"Removed withdrawn articles: {withdraw_counts:,}",
    f"Removed non-research articles: {non_research_counts:,}",
    f"Final number of articles: {final_article_count:,}",
    f"\nTotal removed (should match sum above): {total_removed:,}"
]

print("\n".join(removal_log))

# Save final cleaned dataset
df_filtered_cleaned.to_csv(os.path.join(output_dir, "searchresults-cleaned.csv"), index=False)
# Out:
# Additional Cleaning:  17%|████████████▎                                                             | 1/6 [00:00<00:00,  5.88step/s]
# Identified numeric/nonsense titles: 789
# Additional Cleaning:  33%|████████████████████████▋                                                 | 2/6 [00:01<00:02,  1.38step/s]
# Identified placeholders: 0
# Additional Cleaning:  50%|█████████████████████████████████████                                     | 3/6 [00:02<00:02,  1.35step/s]
# Invalid PaperTitle count (too short/long): 1,734
# Additional Cleaning:  67%|█████████████████████████████████████████████████▎                        | 4/6 [00:16<00:12,  6.03s/step]
# Invalid Abstract count (too short/long): 10,047
# Additional Cleaning:  83%|█████████████████████████████████████████████████████████████▋            | 5/6 [00:16<00:03,  3.92s/step]
# Identified withdrawn: 59
# Additional Cleaning: 100%|██████████████████████████████████████████████████████████████████████████| 6/6 [00:36<00:00,  6.05s/step]
# Identified non-research articles: 2,669
# Removed numeric/nonsense titles & placeholders: 789
# Removed due to title length issues: 1,734
# Removed due to abstract length issues: 10,047
# Removed withdrawn articles: 59
# Removed non-research articles: 2,669
# Final number of articles: 160,045
#
# Total removed (should match sum above): 15,298

# %%
output_dir = './output/'
file_path = './output/searchresults-cleaned.csv'
df_filtered_cleaned = pd.read_csv(file_path, lineterminator='\n')

# %%
tqdm.pandas()
# Store initial row count before cleaning
cleaning_step2_count = len(df_filtered_cleaned)

# Define cleaning function for "PaperTitle"
def clean_paper_title(title):
    if not isinstance(title, str) or title.strip() == "":
        return None  # Return None for empty or non-string values.

    # Use clean-text to clean the title
    title = clean(
        title,
        fix_unicode=True,  # Fix broken unicode characters
        to_ascii=True,     # Transliterate to closest ASCII characters
        lower=False,       # Preserve original casing
        no_line_breaks=True,  # Remove line breaks
        no_urls=True,      # Remove URLs
        no_emails=True,    # Remove email addresses
        no_phone_numbers=True,  # Remove phone numbers
        no_numbers=False,  # Retain numbers
        no_digits=False,   # Retain digits
        no_currency_symbols=True,  # Remove currency symbols
        no_punct=False
    )

    # Additional custom cleaning specific to titles
    title = title.strip()

    # Remove titles that are just numbers or codes
    if re.fullmatch(r"^\d+$", title):  # Only numbers → Remove
        return None

    # Convert ALL CAPS to Title Case
    if title.isupper():
        title = title.title()

    # Remove non-informative titles
    if len(title) <= 3 or re.fullmatch(r"[^A-Za-z0-9]+", title):
        return None

    return title

# Define cleaning function for "Abstract"
def clean_abstract(abstract):
    if not isinstance(abstract, str) or abstract.strip() == "":
        return None

    abstract = clean(
        abstract,
        fix_unicode=True,
        to_ascii=True,
        lower=False,
        no_line_breaks=False,
        no_urls=True,
        no_emails=True,
        no_phone_numbers=True,
        no_numbers=False,
        no_digits=False,
        no_currency_symbols=True,
        no_punct=False,
        replace_with_url="<URL>",
    )

    # Trim whitespace
    abstract = abstract.strip()

    # Remove abstracts that start with specific unwanted text
    blocked_phrases = [
        "Our website uses cookies to enhance your experience.",
        "(Cell Reports"
    ]
    
    # Check if abstract starts with any blocked phrase
    if any(abstract.startswith(phrase) for phrase in blocked_phrases):
        return None  # Mark it as None (to be dropped later)

    return abstract

# Apply cleaning functions

df_filtered_cleaned["PaperTitle"] = df_filtered_cleaned["PaperTitle"].progress_apply(clean_paper_title)
df_filtered_cleaned["Abstract"] = df_filtered_cleaned["Abstract"].progress_apply(clean_abstract)

# Remove rows where "PaperTitle" has 2 or fewer words
def has_min_words(title, min_words=3):
    """Check if title has at least the required number of words."""
    if not isinstance(title, str):
        return False
    return len(title.split()) >= min_words

mask_valid_title = df_filtered_cleaned["PaperTitle"].progress_apply(lambda title: has_min_words(title, 3))
df_filtered_cleaned = df_filtered_cleaned[mask_valid_title]

# Drop any rows where "PaperTitle" or "Abstract" is now empty
df_filtered_cleaned = df_filtered_cleaned.dropna(subset=["PaperTitle", "Abstract"]).reset_index(drop=True)

# Store final row count after cleaning
final_cleaning_step3_count = len(df_filtered_cleaned)
cleaning_step3_rows_removed = cleaning_step2_count - final_cleaning_step3_count

# Save the cleaned dataset
df_filtered_cleaned.to_csv(os.path.join(output_dir,"searchresults-cleaned.csv"), index=False)

# Print summary
print("\nCleaning complete!")
print(f"Initial number of articles: {cleaning_step2_count}")
print(f"Final number of articles after cleaning: {final_cleaning_step3_count}")
print(f"Total number of removed articles: {cleaning_step3_rows_removed}")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 160045/160045 [00:18<00:00, 8883.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 160045/160045 [05:22<00:00, 495.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 160045/160045 [00:00<00:00, 779323.58it/s]
# Cleaning complete!
# Initial number of articles: 160045
# Final number of articles after cleaning: 159950
# Total number of removed articles: 95

# %%
# More specific normalization of PaperTitle and Abstracts, without removing any furhter columns
    
# Store initial row count before cleaning
cleaning_step3_count = len(df_filtered_cleaned)

# Enable tqdm progress bars for pandas operations
tqdm.pandas()

# Helper function to convert ALL CAPS text to sentence case
def to_sentence_case(text):
    if text.isupper():  # Check if it's all caps
        return text.capitalize()  # Convert to sentence case
    return text  # Return unchanged if not all caps


# Cleaning function for PaperTitle
def clean_paper_title(title):
    if not isinstance(title, str) or title.strip() == "":
        return title 
    
    # Remove unwanted keywords at the beginning of the title
    title = re.sub(
        r"^\s*(\*?\[?(invited|keynote|winner|regular paper|blog)\]?\*?)\s*[:\-]*",
        "",
        title,
        flags=re.IGNORECASE
    )
    title = re.sub(r"[_-]{5,}", "", title)  # Remove long underscores or dashes
    title = re.sub(r"^\s*[_]*Abstract[_]*\s*[:\-]*", "", title, flags=re.IGNORECASE)  # Remove "Abstract" heading
    title = re.sub(r"^\s*[\.\,\-\:\;\//\=\s]+", "", title)  # Remove leading . , - : ; // = and spaces
    title = re.sub(r"^\[([^\]]+)\]\.?\s*$", r"\1", title)  # Remove surrounding square brackets + trailing dot
    title = re.sub(r"\s+", " ", title).strip()  # Normalize spaces

    title = to_sentence_case(title)  # Convert to sentence case if all caps

    return title

# Cleaning function for Abstract
def clean_abstract(abstract):
    if not isinstance(abstract, str) or abstract.strip() == "":
        return abstract

    # Remove everything before "introduction" if abstract starts with "You have access"
    if abstract.lower().startswith("you have access"):
        match = re.search(r"\bintroduction\b", abstract, re.IGNORECASE)
        if match:
            abstract = abstract[match.start():]  # Keep everything from "introduction" onwards

    # If it starts with "//", remove everything until "abstract" appears
    if abstract.startswith("//"):
        match = re.search(r"\babstracts?\b", abstract, re.IGNORECASE)
        if match:
            abstract = abstract[match.start():]  # Keep only the part after "abstract"

    # Remove leading colons and spaces
    abstract = re.sub(r"^\s*[:]+\s*", "", abstract)  # Remove any leading : and spaces

    # Remove long underscores/dashes at the start
    abstract = re.sub(r"[_-]{5,}", "", abstract)  # Remove long underscores or dashes
    abstract = re.sub(r"^\s*[_]*Abstract[_]*\s*[:\-]*", "", abstract, flags=re.IGNORECASE)  # Remove "Abstract" heading
    abstract = re.sub(r"^\s*[\.\,\-\:\;\=\s]+", "", abstract)  # Remove leading . , - : ; = and spaces
    abstract = re.sub(r"\s*<[^>]+>\s*", " ", abstract)  # Remove XML-like tags like <CUR>
    abstract = re.sub(r"[,\.]{2,}", ".", abstract)  # Normalize excessive dots and commas
    abstract = re.sub(r"\s+", " ", abstract).strip()  # Normalize spaces

    abstract = to_sentence_case(abstract)  # Convert to sentence case if all caps

    return abstract

# Apply cleaning with progress bar
print("\nCleaning 'PaperTitle' column...")
df_filtered_cleaned["PaperTitle"] = df_filtered_cleaned["PaperTitle"].progress_apply(clean_paper_title)

print("\nCleaning 'Abstract' column...")
df_filtered_cleaned["Abstract"] = df_filtered_cleaned["Abstract"].progress_apply(clean_abstract)

# Store initial row count after cleaning
cleaning_step4_count = len(df_filtered_cleaned)
cleaning_step4_rows_removed = cleaning_step3_count - cleaning_step4_count

# Save cleaned version
df_filtered_cleaned.to_csv('./output/searchresults-cleaned.csv', index=False)


# Print summary
print("\nNormalization complete!")
print(f"Count before cleaning step 4: {cleaning_step3_count:,}")
print(f"Count after cleaning step 4: {cleaning_step4_count:,}")
# Out:
# Cleaning 'PaperTitle' column...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 159950/159950 [00:01<00:00, 91226.91it/s]
# Cleaning 'Abstract' column...
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 159950/159950 [00:29<00:00, 5335.87it/s]
# Normalization complete!
# Count before cleaning step 4: 159,950
# Count after cleaning step 4: 159,950

# %%
# Reload cleaned search results data if needed 
file_path = './output/searchresults-cleaned.csv'
df = pd.read_csv(file_path, lineterminator='\n')

# %%
# Visualise numbers of papers monthly over time
figure_df = df.copy()
# Ensure 'PubDate' is in datetime format
figure_df['PubDate'] = pd.to_datetime(figure_df['PubDate'], errors='coerce')

# Extract year, year-month, and year-week for aggregation
figure_df['Year'] = figure_df['PubDate'].dt.year
figure_df['YearMonth'] = figure_df['PubDate'].dt.to_period('M').astype(str)
figure_df['YearWeek'] = figure_df['PubDate'].dt.to_period('W').astype(str)

# Filter for the years 2015-2025
figure_df = figure_df[figure_df['Year'].between(2015, 2025)]

# Aggregate counts
yearly_counts = figure_df['Year'].value_counts().sort_index()
monthly_counts = figure_df['YearMonth'].value_counts().sort_index()
weekly_counts = figure_df['YearWeek'].value_counts().sort_index()

# Define custom x-axis labels for year shifts
years = list(range(2016, 2027))
shifted_labels = list(range(2015, 2026))

# Generate color palette from 'tab20'
colors = plt.cm.tab20.colors

print("Success!")

# ====== Yearly Publications ======
plt.figure(figsize=(10, 6))
plt.bar(yearly_counts.index + 1, yearly_counts.values, color=colors[0])  # Shift years +1 for alignment

# Styling
plt.xlabel('Year')
plt.ylabel('Number of articles')
plt.title('Publications per year (2015-2025)')
plt.xlim(2015, 2025)
plt.ylim(0, yearly_counts.max() * 1.1)
plt.xticks(years, shifted_labels) 
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# ====== Monthly Publications ======
plt.figure(figsize=(14, 6))
plt.plot(monthly_counts.index[:-2], monthly_counts.values[:-2], marker='o', linestyle='-', color=colors[1], linewidth=2)
plt.xticks([f"{year}-01" for year in range(2015, 2026)], range(2015, 2026))

plt.xlabel('Year')
plt.ylabel('Number of articles')
plt.title('Publications per month (2015-2025)')
plt.xlim(monthly_counts.index.min(), monthly_counts.index.max())
plt.ylim(0, monthly_counts.max() * 1.1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('output/figs/monthlycounts.svg',bbox_inches='tight')
plt.show()

# ====== Weekly Publications ======
plt.figure(figsize=(14, 6))

weekly_counts_smoothed = weekly_counts.rolling(window=4, center=True).mean()
plt.plot(weekly_counts.index, weekly_counts_smoothed, linestyle='-', color=colors[2], linewidth=2)
plt.xticks([f"{year}-W01" for year in range(2015, 2026)], range(2015, 2026))

plt.xlabel('Year')
plt.ylabel('Number of articles')
plt.title('Publications per week (2015-2025)')
plt.xlim(weekly_counts.index.min(), weekly_counts.index.max())
plt.ylim(0, weekly_counts.max() * 1.1)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# Success!
