# %% [markdown]
# <a href="https://colab.research.google.com/github/galenos-project/literature-mining/blob/main/07_22_openalex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import requests
import nltk
from collections import namedtuple
from nltk.corpus import brown
import time  # Import the time module for pausing between requests
import re  # Import the regex module

# Ensure NLTK resources are downloaded
nltk.download('brown')

# Define helper functions
def toAbstract(p):
    # Placeholder function, replace with actual implementation
    return p.get('abstract', '')

def is_en(text, bc_brown, threshold=0.2):
    """
    Function to determine the papers' language
    PARAM text: receiving some text (should be title + abstract text)
    RETURN language: language code, an exception or empty
    RETURN return_code: PASS, FAIL or EMPTY
    """
    if text is None or text == "":
        language = 'NA'
        return_code = 'EMPTY'
    else:
        try:
            tok = set(re.findall(r"\w+", text.lower()))
            if len(tok) <= 0:
                language = 'NA'
                return_code = 'EMPTY'
            elif len(tok & bc_brown.value) / len(tok) <= threshold:
                language = 'non-en'
                return_code = 'PASS'
            else:
                language = 'en'
                return_code = 'PASS'
        except Exception as e:
            language = f"{e}"
            return_code = 'FAIL'
    return return_code, language

def getCitations(c):
    if c is None or c == '':
        return ''
    return '|'.join(c).replace('https://openalex.org/W', '')

def getAuthors(Authors):
    ret = ''
    for a in Authors:
        if ret == '':
            if 'id' in a['author']:
                ret = str(a['author']['id']).replace('https://openalex.org/A', '')
        else:
            if 'id' in a['author']:
                ret += '|' + str(a['author']['id']).replace('https://openalex.org/A', '')
    return ret

def getConcepts(Concepts):
    ret = ''
    for c in Concepts:
        if ret == '':
            ret = c['id'].replace('https://openalex.org/C', '')
        else:
            ret += '|' + c['id'].replace('https://openalex.org/C', '')
    return ret

def calculate_total_pages(total_results, page_size):
    return total_results // page_size + (total_results % page_size > 0)

# Initialize parameters
cursor = '*'
sample_size = 50000
papersDict = []
current_page = 1

# Prepare for API requests
Brown = namedtuple("Brown", field_names=['value'])
bc_brown = Brown(value=set([x.lower() for x in brown.words()]))
headers = {'email': 'avahomiar@gmail.com'}
search_term = '(((mood) OR (depress*) OR (affective disorder)) OR ((psychosis) OR (schizo*) OR (psychotic))) AND ((psychedelic) OR (hallucinogen) OR (entheogen) OR (hallucinogenic) OR (psychotropic)) AND (2014/2024[Date - Publication])'
encoded_search_term = requests.utils.quote(search_term)
baseUrl = f'https://api.openalex.org/works?search={encoded_search_term}'

# Create the directory if it does not exist
output_dir = '/content'
os.makedirs(output_dir, exist_ok=True)

# Fetch and process articles
while cursor:
    print(f"Processing page {current_page}...")

    r = requests.get(url=f"{baseUrl}&per_page=100&cursor={cursor}", headers=headers)

    if r.status_code == 200:
        try:
            theJson = r.json()
        except requests.exceptions.JSONDecodeError:
            print(f"Error decoding JSON response. Status code: {r.status_code}")
            print("Response content:", r.text)  # Print the raw response for debugging
            break  # Exit the loop if JSON decoding fails

        if 'next_cursor' in theJson['meta']:
            cursor = theJson['meta']['next_cursor']
            if 'results' in theJson and theJson['results']:
                for p in theJson['results']:
                    abstract = toAbstract(p)
                    title = p.get('title', '').replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                    pub_date = p.get('publication_date', '')
                    pub_year = p.get('publication_year', '')
                    passed, lang = is_en(title + ' ' + abstract, bc_brown)
                    if lang != 'non-en':
                        papersDict.append({
                            'PaperId': p['id'].replace('https://openalex.org/W', ''),
                            'PaperTitle': title,
                            'Citations': getCitations(p.get('referenced_works', [])),
                            'coFoS': getConcepts(p.get('concepts', [])),
                            'Authors': getAuthors(p.get('authorships', [])),
                            'Abstract': abstract,
                            'Lang': 'en',
                            'PubYear': pub_year,
                            'PubDate': pub_date
                        })
            else:
                cursor = None
        else:
            cursor = None

        # Pause for 1 second between requests to avoid rate limiting
        time.sleep(1)
    else:
        print(f"Request failed with status code {r.status_code}")
        break

df2 = pd.DataFrame(papersDict)
output_file_path = os.path.join(output_dir, 'moodpsychosispsychadelics.csv')
df2.to_csv(output_file_path, sep=',', index=False)

print(f'Done. File saved to {output_file_path}')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# Processing page 1...
# Done. File saved to /content/moodpsychosispsychadelics.csv

# %% [markdown]
# https://openalex.org/works?page=1&filter=title_and_abstract.search%3A%28%28mood%29%20OR%20%28depress%2a%29%20OR%20%28affective%20disorder%29%29%20AND%20%28%28psychosis%29%20OR%20%28schizo%2a%29%20OR%20%28psychotic%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29,publication_year%3A2014-2024&sort=publication_year%3Adesc

# %%
import requests
import pandas as pd
import time
import urllib.parse

# Define search parameters
search_term = '((((mood) OR (depress*) OR (affective disorder)) OR ((psychosis) OR (schizo*) OR (psychotic)) OR ((anxiety) OR (anxious))) AND ((psychedelic) OR (hallucinogen) OR (entheogen) OR (hallucinogenic) OR (psychotropic)))'
publication_year_range = '2014-2024'
base_url = 'https://api.openalex.org/works'

# URL encode the search term
encoded_search_term = urllib.parse.quote(search_term)

# Construct the search URL
search_url = f'{base_url}?filter=title_and_abstract.search:{encoded_search_term},publication_year:{publication_year_range}&sort=publication_year:desc'

# Initialize variables for pagination
cursor = '*'
all_results = []

# Fetch and process articles
while cursor:
    full_url = f"{search_url}&per_page=100&cursor={cursor}"
    print(f"Fetching results from: {full_url}")

    # Make the request to the OpenAlex API
    response = requests.get(full_url)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Extract results and add to the list
        if 'results' in data and data['results']:
            all_results.extend(data['results'])
        else:
            print("No results found or end of results.")
            break

        # Check for the next cursor
        cursor = data['meta'].get('next_cursor', None)

        # Sleep to avoid rate limits
        time.sleep(1)
    else:
        print(f"Request failed with status code {response.status_code}")
        break

# Process the collected results
for result in all_results:
    print(result.get('title', 'No Title'))

print(f"Total number of results fetched: {len(all_results)}")

df = pd.DataFrame(all_results)
output_file_path = '/content/psychadelics.csv'
df.to_csv(output_file_path, index=False)

print(f'Done. File saved to {output_file_path}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Lifetime use of MDMA/ecstasy and psilocybin is associated with reduced odds of major depressive episodes
# National Tele-Mental Health Program in India: A step towards mental health care for all?
# Brief Behavioral Therapy and Bupropion for Sleep and Fatigue in Young Adults With Crohn’s Disease: An Exploratory Open Trial Study
# Hypnotic medication use among inpatients with schizophrenia and major depressive disorder: results of a nationwide study
# Impact of COVID-19 restrictions on behavioural and psychological symptoms in home-dwelling people with dementia: a prospective cohort study (PAN.DEM).
# Prescription Psychedelics: The Road from FDA Approval to Clinical Practice
# Aberrant default mode connectivity in adolescents with early-onset psychosis: A resting state fMRI study
# Multi-centre classification of functional neurological disorders based on resting-state functional connectivity
# Use of Benzodiazepines and Antipsychotic Drugs Are Inversely Associated With Acute Readmission Risk in Schizophrenia
# Prevalence and Appropriateness of Antipsychotic Prescribing in an Italian Prison
# Aggressive challenging behavior in adults with intellectual disability: An electronic register-based cohort study of clinical outcome and service use
# Deuterated dextromethorphan/quinidine for agitation in Alzheimer’s disease
# Differences in prescription patterns between real-world outpatients with bipolar I and II disorders in the MUSUBI survey
# Looking beyond the opioid receptor: A desperate need for new treatments for opioid use disorder
# Pharmacological Treatments for Anhedonia
# Psilocybin for Trauma-Related Disorders
# Trace amine-associated receptors at the cross-road between innate olfaction of amines, emotions, and adult neurogenesis
# Is a Diagnosis of Schizophrenia Spectrum Disorder Associated With Increased Mortality in Patients With COVID-19?
# Management of psychiatric disorders in patients with cancer
# Cannabis Use and the Endocannabinoid System: A Clinical Perspective
# Anterior cingulate cortex in individuals with depressive symptoms: A structural MRI study
# Sex Differences in Psychosis: Focus on Animal Models
# Psychiatric intervention pre- and post-bariatric surgery
# Risk of Major Mental Disorder after Severe Bacterial Infections in Children and Adolescents: A Nationwide Longitudinal Study
# Pharmacological treatment of bipolar disorder in pregnancy: An update on safety considerations
# Pregabalin augmentation of antidepressants in major depression - results from a European multicenter study
# Management of psychiatric disorders in patients with hepatic and gastrointestinal diseases
# Clinical practice guidelines for management of medical emergencies associated with psychotropic medications
# Psychiatric management of patients in intensive care units
# Assessment and management of agitation in consultation-liaison psychiatry
# Neuroimaging Correlates of Treatment Response with Psychedelics in Major Depressive Disorder: A Systematic Review
# Neural function underlying reward expectancy and attainment in adolescents with diverse psychiatric symptoms
# Sexual dysfunction in people treated with long‐acting injectable antipsychotics in monotherapy or polypharmacy: a naturalistic study
# Alcohol and Cannabis Use Disorders
# Role of accredited social health activists in treatment of persons with severe mental illness in the community
# Psychiatric and psychosocial characteristics of suicide completers: A 13-year comprehensive evaluation of psychiatric case records and postmortem findings
# List of essential psychotherapeutic medicines 2019 of India: When science was left behind
# Management of psychiatric disorders during the perinatal period
# Overview of practice of consultation-liaison psychiatry
# Management of psychiatric disorders in patients with chronic kidney diseases
# Management of psychiatric disorders in patients with endocrine disorders
# Hematidrosis: A rare entity – case series and review of literature
# Embedded Psychiatric Services in a Multidisciplinary Amyotrophic Lateral Sclerosis Clinic: An Assessment of Patient Needs and Perceptions
# Pseudothrombocytopenia in a patient with bipolar type 2 disorder on lurasidone: A case report
# Brugada syndrome: should we be screening patients before prescribing psychotropic medication?
# A Prospective Study of Male Depression, Psychotropic Medication Use, and Fecundability
# Practice of telepsychiatry and its current legal status
# Medicolegal issues with reference to ndps and mhca in management and rehabilitation of persons with substance use disorders
# Antipsychotic medications and admission to psychiatric residential treatment facilities among youth in foster care diagnosed with disruptive behavior disorders.
# Psychosexual health and sexual medicine in consultation–Liaison psychiatry
# Management of psychiatric disorders in patients with cardiovascular diseases
# Management of systemic medical emergencies associated with psychotropic medications
# Management of psychiatric disorders with HIV and dermatological disorders
# Pharmacological Interventions for Adults with Autism Spectrum Disorder
# Efficacy and safety studies review of Teraligen usage in psychiatric practice and general medicine
# Psychedelic use in India, its pattern and personal significance – findings from an online survey
# Lysergic Acid Diethylamide Produces Anxiogenic Effects in the Rat Light/Dark Test and Elevated Plus Maze
# Formulation, characterization, and optimization of aripiprazole-loaded lyotropic liquid crystalline nanoparticle for sustained release and better encapsulation efficiency against psychosis disorder
# Ecological Validity of the Montreal Cognitive Assessment in Non-Demented Parkinson’s Disease Patients
# Positive anxiety or depression screen despite ongoing antidepressant prescription in people with epilepsy: A large cross-sectional analysis
# Ethics in psychiatric research
# Ethics and law
# LINKS BETWEEN TRAUMATIC CHILDHOOD EXPERIENCES AND PERSONALITY TOLERANCE IN ADULT AGE
# Primary CNS Lymphoma and Secondary Causes of Mania: A Case Report and Literature Review
# 60 Years of Combining Tranylcypromine
# A Long Trip into the Universe: Psychedelics and Space Travel
# Anxiolytics and psychotropic medications in central serous chorioretinopathy: Caveats and concerns
# Revisiting Forbidden Drugs: Chemical and Pharmacological Perspectives Over Psychedelic Indoleamines and Entactogens as Promising Therapeutic Agents
# Management of mental health issues in Persons with Acute COVID-19 infection and during the post-COVID phase
# Management of medication-induced psychiatric disorders
# Management of psychiatric disorders in patients with respiratory diseases
# Basics for physicians and psychiatrists for effective practice of consultation-liaison psychiatry services
# Clinical profile of dermatitis neglecta with special emphasis on psychiatric comorbidities: A case series of 22 patients from Eastern India
# Cannabinoids: Legal aspects, pharmacology, phytochemistry, probable targets from biological system, and therapeutic potential
# The Role of Occipital Cortex Hyperexcitability in Visual Snow Syndrome
# Strategies to enhance pediatric clinical trial participation
# Interface of law and psychiatric problems in the elderly
# Improvement of Depressive Symptoms Following Surgical Correction of Hallux Valgus and Hallux Rigidus via 1st MTP Fusion
# Measuring Psychotropic Drug Effects and Side Effects
# Rational Prescription of Psychotropic Medications
# Pragmatic issues and prescribing patterns in bipolar disorder: A mental health professional's survey
# Evaluation of Psychotropic Drugs and Falls among Discharged Elderly Patients in Sana’a City, Yemen
# Pharmacological Therapies in Children and Adolescents
# Innovation at life’s end: a moment for hope
# Applying Pharmacogenomics in Drug Therapy of Neurologic and Psychiatric Disorders
# L’évaluation de l’aide humaine en psychiatrie : un enjeu de la réparation du dommage psychique
# Key Insights Into Schizophrenia Misdiagnosis and the Use of Antipsychotics
# Antipsychotics, Antiepileptics, and Fabrication: Are We Making It or Faking It?
# Special Report: Ethical Decision-Making in Contemporary Psychiatric Practice—An Evolving Challenge
# 2021 Articles of Import and Impact
# Novel Neurotherapeutics
# A Retrospective Study of Psychotropic Drug Treatments in Bipolar Disorder During Acute Episodes and Maintenance Periods
# A Molecular Bridge-Like Binding Mode of Buspirone to Bsa: Multispectroscopic and Molecular Docking Investigation
# Preamble
# Assessment of psychiatric disorders in consultation-liaison setting
# Pharmacogenomic testing may be effective in depression treatment, according to study
# Mechanisms of Action of Risperidone and Quetiapine in the Treatment of Agitation, Aggression and Psychosis in Alzheimer's Disease Patients
# Main Drugs of Abuse
# Anxiété en médecine générale : quels types d’autosoins proposer ?
# A study to evaluate the effectiveness of structured teaching programme on level of knowledge regarding problems of substance abuse among higher secondary school students at selected schools in Etawah district
# Baseline prolactin monitoring in patients admitted to a specialized psychogeriatric unit
# Comments on: “Externalizing psychopathology and cognitive functions in patients with early- and late-onset alcohol dependence”
# Falls in the elderly: Prevalence and explanatory factors in Kinshasa: Democratic Republic of Congo
# Shock (1946) - Movie review
# Headache in Brazilian older people in the context of COVID-19 infodemic
# None
# Gender Bias in the Management of Acute Psychiatric Episodes in the Emergency Department: A Cross-Sectional Analysis of the 2017-2019 Triennium
# QT interval prolongation, torsades de pointes and psychotropic medication
# The Activities of the Multidisciplinary Association for Psychedelic Studies as an Example of Modern US Science Diplomacy
# Molecular mechanisms underlying cannabis-induced risk of psychosis
# Focused Neuroregulation in the Treatment and Prevention of Mental and Physical Illness
# Abstract- Poster
# Symposium
# Heteroaromatic Salvinorin a Analogue (P-3l) Elicits Antinociceptive and Anxiolytic-Like Effects
# Application of low-frequency recurrent transcranial magnetic stimulation in the management of aripiprazole-induced akathisias: A case report
# Uso de medicamentos psicotrópicos dispensados em central de abastecimento farmacêutico: aspectos epidemiológicos e fatores associados
# Free Papers Compiled
# Symposium
# Free Papers Compiled
# Abstract- Poster
# DEPENDENȚA DIGITALĂ: PATOLOGIE, REMEDII PSIHOLOGICE ȘI DUHOVNICEȘTI
# Free Papers Compiled
# Trends in the Prevalence of Psychotropic Medications in Children in China from 2013 to 2016
# Psychobiotics: a new way in psychopharmacology, or How do bacteria manage our brain?
# Abstract- Poster
# Clinical considerations with use of psychotropic medications in COVID-19 patients
# Hallucinogen persisting perceptual disorder: a scoping review covering frequency, risk factors, prevention, and treatment
# Characterization of medication side effects in patients with mostly resistant depression in a real-world setting
# Screening for symptoms of anxiety and depression in patients admitted to a university hospital with acute coronary syndrome
# Characterisation of medication side effects in patients with mostly resistant depression in a real-world setting
# Effective connectivity of LSD-induced ego dissolution
# The Activities of the Central Nervous System Following Ethyl Acetate Extract of Mucuna pruriens Seed Administration in Male BALB/c Mice
# Depressive syndrome in gastroenterology
# Psychotropic Polypharmacy among Elderly Patients with Mental Illness in a Malaysian University Hospital: A 10-Year Review of Hospital Databases
# Subjektívne vnímané riziká užívania psychedelík
# Cerebellar Transcranial Direct Current Stimulation in Children with Autism Spectrum Disorder: A Pilot Study on Efficacy, Feasibility, Safety, and Unexpected Outcomes in Tic Disorder and Epilepsy
# Treatment-induced mood switching in affective disorders
# [RETRACTED] Kenai Farms CBD Gummies Price v1
# A network model of the modulation of gamma oscillations by NMDA receptors in cerebral cortex
# UTILIZAÇÃO DE PSICOFÁRMACOS E SINTOMAS DE ANSIEDADE E DEPRESSÃO EM ESTUDANTES UNIVERSITÁRIOS DE LAGARTO/SE DURANTE A PANDEMIA DA COVID-19
# Psychiatry
# Psilocybin microdosing does not affect emotion-related symptoms and processing: A preregistered field and lab-based study
# Psychedelic Therapy's Transdiagnostic Effects: A Research Domain Criteria (RDoC) Perspective
# Psilocybin modulation of dynamic functional connectivity is associated with plasma psilocin and subjective effects
# Drug Treatment of Psychiatric Symptoms Occurring in the Context of Other Disorders
# Psychotropic Drugs in Special Conditions
# The emerging science of microdosing: A systematic review of research on low dose psychedelics (1955 – 2021)
# A Quantitative and Qualitative Report of Psilocybin Induced Mystical-Type Experiences and Their Relation to Lasting Positive Effects
# Smartphone Psychological Therapy During COVID-19: A Study on the Effectiveness of Five Popular Mental Health Apps for Anxiety and Depression
# Announcement of two special issues: behavioural pharmacology of synaptopathies and psychedelic drugs
# Data_Sheet_1.docx
# Psychopharmacology in the Critical Care Setting
# Liaison Psychiatry During the Peak of the Coronavirus Pandemic: A Description of Referrals and Interventions
# A Spectrum of Selves Reinforced in Multilevel Coherence: A Contextual Behavioural Response to the Challenges of Psychedelic-Assisted Therapy Development
# Maternal Perinatal Depression and Risk of Neurodevelopmental Disorders in Offspring: Preliminary Results from the SOS MOOD Project
# Trajectory and Predictors of Mental Health Symptoms and Wellbeing in Newly Admitted Nursing Home Residents
# Experiences of advanced psychiatric nurses regarding the need for prescriptive authority in KwaZulu-Natal
# Psychiatrists should investigate their patients less
# Chronopharmacology of alcoholism
# Psychotropic medicine consumption in 65 countries and regions, 2008–19: a longitudinal study
# Phytocannabinoids and schizophrenia: Focus on adolescence as a critical window of enhanced vulnerability and opportunity for treatment
# Betaine prevents and reverses the behavioral deficits and synaptic dysfunction induced by repeated ketamine exposure in mice
# Enhancing equity-oriented care in psychedelic medicine: Utilizing the EQUIP framework
# Impact of the COVID-19 Pandemic on the General Mental Health in Sweden: No Observed Changes in the Dispensed Amount of Common Psychotropic Medications in the Region of Scania
# Psychotropic medications sales during COVID-19 outbreak in Italy changed according to the pandemic phases and related lockdowns
# Bipolar women's antepartum psychotropic exposure and offspring risk of attention-deficit/hyperactivity disorder and autism spectrum disorder
# Psychotropic Drug Treatment Patterns in Persons with Fragile X Syndrome
# Identifying pathways to early‐onset metabolic dysfunction, insulin resistance and inflammation in young adult inpatients with emerging affective and major mood disorders
# Antipsychotics and COVID-19: the debate goes on
# Cannabis Essentials: Tools for Clinical Practice.
# Severe Anxiety Post-COVID-19 Infection
# Screening for cognitive impairment in systemic lupus erythematosus: Application of the Montreal Cognitive Assessment (MoCA) in a Greek patient sample
# <i>Letter to the Editor:</i> The Impact of the COVID-19 Pandemic on the Mental Health of Youth with Developmental Disabilities
# Psychotropics and COVID-19: An analysis of safety and prophylaxis
# Beyond access to psychotropic medicines: treatment coverage amid COVID-19
# Plasma proteomic data in bipolar II disorders and major depressive disorders
# Disparities of Mental Health Service Needs and Utilization Among Older Adults
# Antipsychotics and COVID-19: the debate goes on – Authors' reply
# Associations between sleep and Alzheimer’s disease biomarkers within the EPAD cohort
# La psychothérapie assistée par la MDMA dans la prise en charge du syndrome de stress post-traumatique
# 91-Year-Old Man With Recurrent Falls
# Special Report: Complementary Alternative and Integrated Medicine Can Help Meet Challenges of COVID-19
# Psychedelic Drugs for Mental Disorders and Human Potential: Placebo or Panacea
# Marijuana, Hallucinogen Use Reach Historic Levels Among Young Adults
# Dementia Care: Addressing Pain and Maximizing Comfort
# Prescription Patterns of Anti-dementia and Psychotropic Drugs in People Living With Dementia in China
# P.0472 Immunoglobulins G hydrolyze recombinant fragments of NMDA receptor NR1 and NR2 subunits in schizophrenia and multiple sclerosis: preliminary results
# DataSheet1.docx
# P.0177 Partial ornithine-transcarbamylase deficiency, autoimmunity and psychosis – a complex case report
# Anorexia nervosa, conduct disorder, and the juvenile justice system: a case of applying traditional treatment modalities in a non-traditional setting
# Psychiatric Boarders on Pediatric Medical Floors: A Call for Action and Collaboration
# Anticholinergic Burden Among Hospitalised Older Adults with Psychiatric Illnesses- A Retrospective Study
# Analise Demografica e Socioeconomica do Uso e do Acesso a Medicamentos
#   Antidepressivos no Brasil
# Anesthetic Considerations for Patients on Psychotropic Drug Therapies
# Consenting to consent
# MDMA‐Assisted Psychotherapy for Treatment of Posttraumatic Stress Disorder: A Systematic Review With Meta‐Analysis
# A Phase 1, Dose-Ranging Study to Assess Safety and Psychoactive Effects of a Vaporized 5-Methoxy-N, N-Dimethyltryptamine Formulation (GH001) in Healthy Volunteers
# Detailing the effects of polypharmacy in psychiatry: longitudinal study of 320 patients hospitalized for depression or schizophrenia
# Mental health in context: structural vulnerability and support in primary care
# An Integrative Approach to Ketamine Therapy May Enhance Multiple Dimensions of Efficacy: Improving Therapeutic Outcomes With Treatment Resistant Depression
# High cognitive demand tasks may detect mild alterations in executive functions in American football players: A pilot study
# Psychedelics for the treatment of depression, anxiety, and existential distress in patients with a terminal illness: a systematic review
# Incremento de la ingesta de alcohol y drogas como estrategia de afrontamiento en trabajadores hospitalarios durante el brote de COVID-19: Estudio transversal.
# Exploring the use of psychotropic medication in cardiac patients with and without anxiety and its association with 1-year mortality
# Gastrointestinal Manifestation and Bipolar Disorder: About a Clinical Case
# Acute Effects of Psilocybin After Escitalopram or Placebo Pretreatment in a Randomized, Double‐Blind, Placebo‐Controlled, Crossover Study in Healthy Subjects
# Selection of psychotropics in dermatologic practice
# Subgrouping time-dependent prescribing patterns of first-onset major depressive episodes by psychotropics dissection
# Psychiatrists Have a Role in Managing Pediatric Pain
# Adults who microdose psychedelics report health related motivations and lower levels of anxiety and depression compared to non-microdosers
# The Association Between Concentrations of Arginine, Ornithine, Citrulline and Major Depressive Disorder: A Meta-Analysis
# Practical Handbook of Psychopharmacology
# Association of SARS-CoV-2 Infection With Psychological Distress, Psychotropic Prescribing, Fatigue, and Sleep Problems Among UK Primary Care Patients
# Trajectories of depression and anxiety symptoms during psychological therapy for common mental health problems
# Psychedelic medicines for mood disorders: current evidence and clinical considerations
# Psychedelic medicines for mood disorders: current evidence and clinical considerations.
# Lysergic acid diethylamide induces increased signalling entropy in rats’ prefrontal cortex
# Abuse and dependence potential of sphingosine-1-phosphate (S1P) receptor modulators used in the treatment of multiple sclerosis: a review of literature and public data
# Frequency of Iatrogenic Sexual Dysfunction Associated with Antihypertensive Compounds
# Providing Psychological Support to Parents of Childhood Cancer Survivors: ‘Cascade’ Intervention Trial Results and Lessons for the Future
# Poster Presentation
# Emotional Distress in Cancer Patients During the First Wave of the COVID-19 Pandemic
# Psychiatric Adverse Effects of Levetiracetam in Malignant Glioma Populations; a Retrospective Cohort Study
# Mental Health Among Patients with Non-Hodgkin Lymphoma: A Danish Nationwide Study of Psychotropic Drug Use in 7,201 Patients and 36,005 Matched Comparators
# Plasma circulating cell-free mitochondrial DNA in depressive disorders
# Psychedelic Experiences During the Early COVID-19 Pandemic: Findings From an International Online Survey
# Lithium Toxicity and Neuroleptic Malignant Syndrome in a Patient with Bipolar Disorder
# Lithium Toxicity and Neuroleptic Malignant Syndrome in a Patient with Bipolar Disorder
# The risk of dementia in patients using psychotropic drugs: Antidepressants, mood stabilizers or antipsychotics
# Secondary Mania induced by <scp>TNF</scp>‐α inhibitors: A systematic review
# Long-term Outcome of Deep Brain Stimulation of the Ventral Part of the Anterior Limb of the Internal Capsule in a Cohort of 50 Patients With Treatment-Refractory Obsessive-Compulsive Disorder
# People with epilepsy and intellectual disability: More than a sum of two conditions
# Do depressive symptoms link chronic diseases to cognition among older adults? Evidence from the Health and Retirement Study in the United States
# Ayahuasca and the traveller: A scoping review of risks and possible benefits
# Systemic lupus erythematosus and autoimmune features in chronic hospitalized patients with schizophrenia
# Sulfation of glycosaminoglycans depends on the catalytic activity of lithium-inhibited phosphatase BPNT2 in vitro
# The challenges of implementing evidence‐based therapy for irritable bowel syndrome in Asia
# Suicidal cut‐throat wound during LSD intoxication
# Risk of long-term benzodiazepine and Z-drug use following the first prescription among community-dwelling adults with anxiety/mood and sleep disorders: a retrospective cohort study
# Treatment of imipramine-induced hyperpigmentation with quality-switched ruby and picosecond lasers
# Can Knowledge of Genetic and Environmental Causal Factors of Fatal and Nonfatal Suicidal Behavior Be Translated Into Better Prevention?
# Advancements of Transdermal Patches in Psychiatric Disorders
# To Minimize Medication Withdrawal, Taper Slowly
# Key Guidelines for Gradual Dosage Reductions of Psychotropic Medications
# Fluctuating Decision-Making in People with Mental Illness
# Intentional Overdose Prevention in the Era of the 90-Day Prescription
# Managing Serious Mental Illness: Team Training, Antipsychotic Therapy, and Research Trends
# Serious Mental Illness in Post-Acute and Long-Term Care:Building Knowledge, Sharing Care
# Opening Up About My Struggle With Recurring Depression
# A “GENERAL THEORY OF MENTAL SUFFERING”, AND THE ROLE OF AN INNOVATIVE NARRATIVE THERAPEUTIC APPROACH
# Psychotropic medication prescribing during the COVID-19 pandemic
# Patient Characteristics and Emergency Treatment Orders in Three Florida Inpatient Psychiatric Units
# The MATRICS Consensus Cognitive Battery: Psychometric Properties of the Chinese Version in Young Patients With Major Depression Disorder
# A Clinical Review of the Psychiatric Sequelae of Primary Hyperparathyroidism
# Comparative study of the anxiety, depression and complaience of patients with somatoform disorders before and after treatment
# P-180 Dementia, stress and distress – supporting the palliative care workforce
# Factores psicosociales y vulnerabilidad al estrés en viajeros en aislamiento para vigilancia de COVID-19.
# CREATING CHARACTER BUILDING AGAINST DRUGS ABUSE ON YOUTH ORGANIZATION
# Comorbidity and Treatment in Older Psychiatric In-patients—A Retrospective Study in a Chinese Psychiatric Hospital
# Пароксетин при лечении депрессивных и тревожно-фобических состояний у больных бронхиальной астмой (пилотное исследование)
# From psychiatry to neurology: Psychedelics as prospective therapeutics for neurodegenerative disorders
# Bipolar Patients and Bullous Pemphigoid after Risperidone Long-Acting Injectable: A Case Report and a Review of the Literature
# Why was early therapeutic research on psychedelic drugs abandoned?
# Lithium toxicity at therapeutic doses as a fallout of COVID-19 infection: a case series and possible mechanisms
# A study of abnormal cannabidiols system‐mediated cardiovascular protection in disrupted gut/brain axis associated depression
# Finding the divine within: exploring the role of the sacred in psychedelic integration therapy for sexual trauma and dysfunction
# Patterns and Predictors of Healthcare Use among Adolescent and Young Adult Cancer Survivors versus a Community Comparison Group
# The Pharmacological Management of Emergencies in Child and Adolescent Psychiatry
# Acute effects of oral delta‐9‐tetrahydrocannabinol (THC) on autonomic cardiac activity and their relation to subjective and anxiogenic effects
# Psychotropic properties of a potential anticonvulsant of 5-[(Z)-(4-nitrobenzylidene)]-2- (thiazol-2-ylimino)-4-thiazolidinone
# The Benzydamine Experience: A Systematic Review of Benzydamine Abuse
# Current Clinical Psychopharmacology in Borderline Personality Disorder
# Covid-19 Pandemic Impact in Pediatricians: Stress Factors and their Consequences
# Decision letter for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Lifetime use of psychedelics is associated with better mental health indicators during the COVID-19 pandemic
# Sub-acute and long-term effects of ayahuasca on mental health and well-being in healthy ceremony attendants: A replication study
# Is MDD the right target for early-stage psychedelic-assisted therapy trials?
# The Possibilities of Safe Lithium Therapy in the Treatment of Neurological and Psychoemotional Disorders
# Management of Drug-induced Weight Gain in Persons Receiving Psychotropic Drugs
# Bridging the Gap? Altered Thalamocortical Connectivity in Psychotic and Psychedelic States
# Psychiatric Aspects of Epilepsy: A Review
# Case Report: Magic Mushroom (Psilocybe Cubensis) Intoxication
# Effects of Dynamic Bedroom Lighting On Measures of Sleep and Circadian Rest-Activity Rhythm in Inpatients With Major Depressive Disorder
# Gestational and Neurodevelopmental Outcomes Associated With Antipsychotic Drug Exposure During Pregnancy
# Classic Psychedelic Use and Mechanisms of Mental Health: Exploring the Mediating Roles of Spirituality and Emotion Processing on Symptoms of Anxiety, Depressed Mood, and Disordered Eating in a Community Sample
# Ketamine and other glutamate receptor modulators for depression in adults with bipolar disorder
# Comparing the evidential strength for psychotropic drugs: a Bayesian meta-analysis
# Clozapine treatment in a wider context: From before eligibility to life beyond clozapine
# Low doses of LSD reduce broadband oscillatory power and modulate event-related potentials in healthy adults
# The impact of COVID-19 lockdown on gambling habit: A cross-sectional study from Italy
# ZORRO: When the mask falls off—Comment
# Mouldy Matriarchs and Dangerous Daughters
# Psychedelics and Other Psychoplastogens for Treating Mental Illness
# Delix to synthesize psychedelic drugs
# Persisting Effects of Ayahuasca on Empathy, Creative Thinking, Decentering, Personality, and Well-Being
# Ethnoracial health disparities and the ethnopsychopharmacology of psychedelic-assisted psychotherapies.
# Correction to: Toxicity of ayahuasca after 28 days daily exposure and effects on monoamines and brain-derived neurotrophic factor (BDNF) in brain of Wistar rats
# Clinical and psychological factors associated with interdose opioid withdrawal in chronic pain population
# The Adolescent Mental Health Crisis in the Context of COVID-19: A Pediatric Resident Perspective
# Anti-epileptic drugs and hepatitis C therapy: Real-world experience
# Pharmacological potential of JWH133, a cannabinoid type 2 receptor agonist in neurodegenerative, neurodevelopmental and neuropsychiatric diseases
# Clozapine, Long-Acting Injectables (and Polypharmacy?) Superior in U.S. and International Registries
# μ Opioid Antagonist Naltrexone Partially Abolishes the Antidepressant Placebo Effect and Reduces Orbitofrontal Cortex Encoding of Reinforcement
# Extreme hyponatraemia due to primary polydipsia and quetiapine-induced SIAD
# Perioperatives Management psychiatrischer und neurologischer Dauermedikation
# Management of Duchenne Muscular Dystrophy With Ayurvedic Measures- A Case Study
# The impact of resilience and loneliness during COVID-19 pandemic on youth’s (18 – 25 years old) mental health
# Recreational cannabis consumption: a public health perspective
# Differences in COVID-19 screening, diagnosis, and hospitalization rates among US pregnant women with and without a substance use disorder
# Predictors of relapse following a stepwise psychopharmacotherapy regime in patients with depressive disorders
# 17.2 Pharmacological Treatment of Avoidant/Restrictive Food Intake Disorder (ARFID): A Review
# S951 Increased Psychiatric Diagnoses and Utilization in High-Risk Patients with Inflammatory Bowel Disease Flare
# Psychiatry Patients With Long COVID-19 Need Team-Based, Coordinated Care
# O011 Associations between sleep and Alzheimer’s disease biomarkers within the EPAD cohort
# 29.5 The Relationships Between Family Functioning and Dimensional Psychopathology
# 43.1 Exploring Trends in Pediatric Phencyclidine Use in the USA: A Retrospective Analysis Using Big Data
# 6.1 THE HISTORY OF PSYCHEDELIC USE AS TREATMENT: WHAT CAN WE LEARN?
# Le maniement des psychotropes dans les maladies du système nerveux central
# Early Psychosis Intervention Shows Robust Real-World Effectiveness
# NOT JUST FOR HIPPIES ANYMORE: A REVIEW OF THE USE OF PSYCHEDELICS IN TREATMENT, RESEARCH, REGULATORY, AND ETHICAL ISSUES, AND IMPLICATIONS FOR THE PEDIATRIC POPULATION
# Psychosexual Problem in Remitted Psychiatric Patients
# 6.3 CURRENT RESEARCH ON PSILOCYBIN TREATMENT ON END-OF-LIFE ANXIETY AND MDMA TREATMENT OF SOCIAL ANXIETY IN AUTISM SPECTRUM DISORDER
# Electroconvulsive therapy and haloperidol treatment of delirious mania in the youngest adolescent: a unique case report
# 1.13 Adverse and Benevolent Childhood Experiences Association With Self-Reported Psychiatric Symptoms in the Colorado Adolescent Maternity Program
# 4.4 AGITATION MANAGEMENT IN INPATIENT SETTINGS
# S517 Comorbid Psychiatric Conditions Are Associated With Increased Risk of Gastrointestinal Symptoms Following Successful Fecal Microbiota Transplantation for Clostridioides difficile Infection
# 428 - Reflections on geriatric psychopharmacology in Portugal
# Novel antidepressant drugs: Beyond monoamine targets
# A unique case of neurofibromatosis 1 (NF1) with Cotard syndrome – A case report
# 884 Effect of COVID-19 pandemic on the blood pressure of children and adolescents with ADHD: implications for clinical practice
# Case of Somatoform Disorder Due to COVID-19 Induced Trauma
# Rediscovering Psilocybin as an Antidepressive Treatment Strategy
# Psychiatric clinical decision making in anti-NMDA receptor encephalitis
# Binocular rivalry perceptual memory in schizophrenia and in acute ayahuasca administration
# Alcohol Withdrawal
# Assessing the relationships between neurological and psychiatric diseases with astrocyte subtypes and psychotropic medications
# Brain 5-HT1A Receptor PET Binding, Cortisol Responses to Stress, and the Familial Transmission of Suicidal Behavior
# Association of mental health diagnosis with race and all‐cause mortality after a cancer diagnosis: Large‐scale analysis of electronic health record data
# Psychedelic mushrooms in the USA: Knowledge, patterns of use and association with health outcomes
# Psychological symptoms in difficult‐to‐sedate critical care survivors
# Adrafinil: Psychostimulant and Purported Nootropic?
# Critical Period Plasticity as a Framework for Psychedelic-Assisted Psychotherapy
# Psychotropic prescribing rates and pharmacogenomic testing implications for autism in the Canadian primary care sentinel surveillance network
# Cognitive attentional syndrome and metacognitive beliefs as potential treatment targets for metacognitive therapy in bipolar disorder
# Sleep Disturbance in Individuals at Clinical High Risk for Psychosis
# Disparities in Utilization of Psychiatry Services Among Home Care Clients: The Tale of Two Canadian Jurisdictions
# Qi-Regulating and Blood Circulation-Promoting Therapy Improves Health Status of Stable Angina Pectoris Patients with Depressive Symptoms
# Lamotrigine in the maintenance treatment of bipolar disorder
# Depressive symptoms in patients with epilepsy and clinically associated features in a single tertiary center
# The therapeutical role of psychedelic drugs in treatment of mental disorders
# Assessing the effects of methodological differences on outcomes in the use of psychedelics in the treatment of anxiety and depressive disorders: A systematic review and meta-analysis
# Excess mortality from cancer in people with mental illness—Out of sight and out of mind
# Ketamine and other glutamate receptor modulators for depression in adults with unipolar major depressive disorder
# Plasma Levels of the Cytokines B Cell-Activating Factor (BAFF) and A Proliferation-Inducing Ligand (APRIL) in Schizophrenia, Bipolar, and Major Depressive Disorder: A Cross Sectional, Multisite Study
# Science, Medicine, and the Anesthesiologist
# Pharmacological Treatments for Borderline Personality Disorder: A Systematic Review and Meta-Analysis
# Pharmacokinetic and pharmacodynamic properties of aerosolized (“vaped”) THC in adolescent male and female rats
# The Mark Sheldon Remote Mental Health Team: an evaluation of patient demographics, diagnoses and clinical management in very remote Central Australia
# Risques d’Accidents de la Route chez les Conducteurs de Bus de Kinshasa et Signes Évocateurs du Syndrome d’Apnée du Sommeil
# LSD-stimulated behaviors in mice require β-arrestin 2 but not β-arrestin 1
# Understanding the impact of psychosocial working conditions on workers’ health: we have come a long way, but are we there yet?
# Associations Between Prenatal Exposure to Serotonergic Medications and Biobehavioral Stress Regulation: Protocol for a Systematic Review and Meta-analysis (Preprint)
# COVID-19 lockdown impact on mental health in a large representative sample of Italian adults
# Anticholinergic Medication Burden–Associated Cognitive Impairment in Schizophrenia
# Symptoms of Mental Health Disorders in Critical Care Physicians Facing the Second COVID-19 Wave
# Improving cognitive functioning in major depressive disorder with psychedelics: A dimensional approach
# Characteristics of discharge prescriptions for patients with schizophrenia or major depressive disorder: Real-world evidence from the Effectiveness of Guidelines for Dissemination and Education (EGUIDE) psychiatric treatment project
# A North American prospective study of depression, psychotropic medication use, and semen quality
# N, N-dimethylglycine Protects Behavioral Disturbances and Synaptic Deficits Induced by Repeated Ketamine Exposure in Mice
# Case Report: Treatment of Oral Lichen Planus With a Focus on Psychological Methods
# Myrsinoic acid B from Myrsine coriacea reverses depressive-like behavior and brain oxidative stress in streptozotocin-diabetic rats
# Psychédéliques, psychothérapie et symbolisation : une revue de littérature dans le champ de la dépression
# Matched emotional supports in health care (MESH) framework: A stepped care model for health care workers.
# Osteopathic Manipulative Treatment in Patients with Anxiety and Depression: A Pilot Study
# <scp>Self‐reported</scp> medication use as an alternate phenotyping method for anxiety and depression in the <scp>UK</scp> Biobank
# Psychotropic medication use among women seeking assisted reproductive technology (ART) therapy: A cross-sectional study
# Improvement in Memory Deficits With Memantine in Mania Secondary to Traumatic Brain Injury and Preexisting Perinatal Birth Injury
# Review Highlights Gaps in Knowledge of Perinatal Mental Health
# Le score des pictogrammes pour les patients conducteurs
# Propriété égolytique des psychédéliques et intérêts dans le traitement de la dépression
# Study Examines Cognitive Effects of Antipsychotics, Other Medications
# Insights Into Improving Clinical Outcomes Across Psychiatric Disorders and Medical Comorbidities
# SY4-1. Reliable urinary screening tests for preeclampsia
# 1621P Emotional distress in cancer patients during the first wave of the COVID-19 pandemic in Madrid
# Effects of prolonged methylphenidate treatment on amygdala reactivity and connectivity: a randomized controlled trial in stimulant treatment-naive, male participants with ADHD
# Decision letter for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Welcome from the Editors
# Atrial natriuretic peptide (ANP) as an endogenous anxiolytic in patients with heart failure? – No replication of previous results showing an inverse association of anxiety and plasma ANP parameters
# Natural relativism in lieu of moral absolutism
# Medicinal cannabis in children and adolescents with autism spectrum disorder: A scoping review
# Treatment of depression: Are psychotropic drugs appropriately dosed in women and in the elderly? Dosages of psychotropic drugs by sex and age in routine clinical practice
# None
# Prevalence of dental disorders among people with mental illness: An umbrella review
# Acute Necrotizing Pancreatitis following Long-Term Antipsychotic Use
# A-1 Neuropsychiatric Symptoms over Time in Autopsy-Confirmed Alzheimer’s Disease, Lewy Body Disease, and Mixed Pathology
# A-3 History of Traumatic Brain Injury and the Course of Neuropsychiatric Symptoms among those with Autopsy-Confirmed Alzheimer’s Disease
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# A delicate balance: Psychotropic polypharmacy and anti‐cholinergic use are correlated with fall incidence in Australian inpatients with dementia
# Antipsychotic polypharmacy in adult patients diagnosed with schizophrenia: A retrospective study
# Oscillatory Components of Psychedelic Experience
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Trends in Psychotropic Medication Prescriptions in Urban China From 2013 to 2017: National Population-Based Study
# Integrating Mental Health in Safety-net Primary Care
# GAMBARAN PSIKOLOGI WARGA KABUPATEN MAGELANG SELAMA PANDEMI COVID-19
# Phytochemical and Spectral analysis of Argoclavine; A potent Psychoactive substance present in the seeds of Argyreia nervosa plant
# Ayahuasca may help to improve self‐compassion and self‐criticism capacities
# Psychosis Without Meaning: Creating Modern Clinical Psychiatry, 1950 to 1980
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# STEROID INDUCED PSYCHOSIS IN A CASE OF ERYTHEMA MULTIFORME MAJOR.
# What can we learn from the history of research on psychedelic drugs in the addictions?
# Examining the Potential Synergistic Effects Between Mindfulness Training and Psychedelic-Assisted Therapy
# On Perception and Consciousness in HPPD: A Systematic Review
# Depression, anxiety, psychotropic drugs, and acute myocardial infarction: large prospective study of United Kingdom women
# Colombian consensus of treatment with pure cannabidiol (CBD) in Psychiatry
# Review of Psychotropic Agents Associated with Sialorrhoea, Except Clozapine
# Assessment of retinal photosensitivity as an objective indicator of expression psychodense effect
# Clenbuterol Attenuates Immune Reaction to Lipopolysaccharide and Its Relationship to Anhedonia in Adolescents
# Analysing Biochemical Parameters and Developing Risk Prediction Models in Patients with Schizophrenia and Bipolar Disorder
# Effectiveness of neurotropic therapy in the treatment of non-psychotic mental disorders in patients who have suffered a cerebral stroke
# Salud mental y pandemia de COVID-19 en Ecuador
# Classic Psychedelic Coadministration with Lithium, but Not Lamotrigine, is Associated with Seizures: An Analysis of Online Psychedelic Experience Reports
# THC-induced behavioral stereotypy in zebrafish as a model of psychosis-like behavior
# COVID-19-Impfung unter Psychopharmakotherapie
# Evaluation and Maintenance of Behavioral Interventions for 22q11.2 Deletion Syndrome
# Cancer Healthcare Workers’ Perceptions toward Psychedelic-Assisted Therapy: A Preliminary Investigation
# Cannabidiol Modulates the Motivational and Anxiety-Like Effects of 3,4-Methylenedioxypyrovalerone (MDPV) in Mice
# Suicidal behaviour in older age: A systematic review of risk factors associated to suicide attempts and completed suicides
# Ayahuasca, an ancient substance with traditional and contemporary use in neuropsychiatry and neuroscience
# Affective disorders impact prevalence of Flavonifractor and abundance of Christensenellaceae in gut microbiota
# Efficacité des psychédéliques en psychiatrie, une revue systématique
# Why is COVID-19 associated with mental illness?
# The Creation of a Comprehensive Adolescent and Young Adult Cancer Survivorship Program: “Lost in Transition” No More
# Lack of Associations Between C-Reactive Protein and Mood and Anxiety Symptoms in Adolescents
# Psychotherapy-supported MDMA treatment for PTSD
# Illness stage and predominant polarity in bipolar disorder: Correlation with burden of illness and moderation of treatment outcome
# Psychological Healthcare Burden Lessens After Hip Arthroscopy for Those With Comorbid Depression or Anxiety
# Should gabapentinoids be prescribed long-term for anxiety and other mental health conditions?
# Pharmacologic Similarities and Differences Among Hallucinogens
# Mental health mediators of subjective cognitive concerns among World Trade Center responders
# Any Questions? A Sober Look at MDMA
# Non‐pharmacological intervention in functional dyspepsia: Is this the way forward?
# Risk factors for early-phase clozapine discontinuation: A nested case-control study
# Adrenal adenoma as a cause of atypical psychosis: Presentation, diagnosis, surgical technique and outcome (case report with a brief literature review)
# Sertraline Pediatric Registry for the Evaluation of Safety: Design and Clinical Characteristics of Pediatric Patients Prescribed Sertraline
# Insights into the Use of Digital Tools for People with Mental Health Disorders
# The cranial windows of perception
# Toxicology Rounds
# Psychedelic Therapy Hits Another Milestone, But Caution Urged
# Malignant Catatonia: Sepsis or Psychiatric Emergency?
# The first male case with fluoxetine induced hair loss and review of the literature.
# The Right to Choose
# Special Report: Guidance on Managing Side Effects of Psychotropics
# Differences that Make No Difference and Ambiguities that Do
# Interactions between psychedelics and mood stablisers
# Journal Digest: Laughing Gas for Depression; Psychotropic Prescriptions During Pandemic; Genetic Risk for Alzheimer’s Psychosis; and More
# Stahl's Essential Psychopharmacology
# The Potential Role of Serotonergic Hallucinogens in Depression Treatment
# Targeting Dopamine and Serotonin Receptors for Psychosis, Mood, and Beyond: So-Called “Antipsychotics”
# Chronic Pain and Its Treatment
# The Utility of Pharmacogenetic-Guided Psychotropic Medication Selection for Pediatric Patients: A Retrospective Study
# Serotonin Heteroreceptor Complexes and Their Integration of Signals in Neurons and Astroglia—Relevance for Mental Diseases
# Cortisol and Oxytocin Could Predict Covert Aggression in Some Psychotic Patients
# Life skills education: a coping strategy against substance abuse
# Intra-household Variation in Pathways to Care for Epilepsy and Mental Disorders in Eastern Uganda
# Recreation and Realization: Reported Motivations of Use Among Persons Who Consume Psychedelics in Non-Clinical Settings
# Dissociative symptoms with intravenous ketamine in treatment-resistant depression exploratory observational study
# Psychedelic drug use and schizotypy in young adults
# Impact of treatment-related discussions on healthcare resource use and costs among patients with severe mental illness
# Pharmacotherapy, drug-drug interactions and potentially inappropriate medication in depressive disorders
# Cognitive performance in older‐age bipolar disorder: Investigating psychiatric characteristics, cardiovascular burden and psychotropic medication
# Mental Health and Psychological Wellbeing during the COVID-19 Lockdown: A Longitudinal Study in the Balearic Islands (Spain)
# Psychophysiological Aspects in the Clinical Picture of Disease in Patients Who Received Local Radiation Injury
# The Implications of Adverse Pharmacologic Reactions and Complex Pathogenic Mechanisms in Schizophrenia
# COVID-19 Lockdown Effect on Not Institutionalized Patients with Dementia and Caregivers
# Food insufficiency and mental health service utilisation in the USA during the COVID-19 pandemic
# Maternal 15q Duplication Syndrome
# LSD, madness and healing: Mystical experiences as possible link between psychosis model and therapy model
# Research abuses against people of colour and other vulnerable groups in early psychedelic research
# O uso de psicofármacos e/ou psicotrópicos: Uma revisão integrativa
# Mental Healthcare Utilization of Transgender Youth Before and After Affirming Treatment
# The highs and lows of drugs use: acute effects of cannabis, cocaine and MDMA on impulsivity, cognition and subjective experience
# Medicinal cannabis: knowledge, beliefs, and attitudes of Colombian psychiatrists
# Prevalence of metabolic syndrome and its correlation with sexual dysfunction in adult psychiatric patients treated with psychotropics in a tertiary care hospital
# Decision letter for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Mental Health and Traumatization of Newly Arrived Asylum Seeker Adults in Finland: A Population-Based Study
# Mental health, substance abuse, prison victimization and suicide attempts amongst incarcerated women
# Review for "The risk of dementia in patients using psychotropic drugs: antidepressants, mood stabilizers or antipsychotics"
# Philosophy of Psychedelics
# Registered clinical studies investigating psychedelic drugs for psychiatric disorders
# A Cluster Randomized Controlled Trial Testing the Impact of Function and Behavior Focused Care for Nursing Home Residents With Dementia
# Altered states phenomena induced by visual flicker light stimulation
# Toxicology of Psychoactive Substances
# Fear of spreading COVID-19 infection in a female with psychotic illness leading to suicidal and homicidal attempt: A case report
# The prevalence and risk factors for overweight/obesity among Turkish children with neurodevelopmental disorders
# Ethical Issues in Caring for Older Adults
# Trends in Substance Abuse Disorders Among Patients Hospitalized for Heart Failure in the United States
# COVID-19 y adultos mayores con deterioro cognitivo: ¿puede influir el aislamiento social en la enfermedad?
# Prevalence of and Risk Factors for Depressive Symptoms and Antidepressant Use in Young Australian Women: A Cross-Sectional Study
# Flexible Applications of Family-Based Therapy for Youth with Bipolar Spectrum Disorders
# On the need for a natural philosophy of psychedelics
# Weighing in on Children with Autism: Rethinking Strategies for Weight Management
# Special Report: ‘Will They See Me?’ How to Rebuild Patient Relationships Frayed by Pandemic
# Slow-Release Oral Morphine May Help Patients With OUD
# Mental health care among marginalized populations in the United States
# A REVIEW ON DRUG UTILIZATION STUDY OF PSYCHOTROPIC DRUGS
# Psychotropic Medication Adherence in Children and Adolescents
# Treatment patterns and appropriateness of antipsychotic prescriptions in patients with schizophrenia
# ...
# Subjective sleep quality in non-demented older adults with and without cognitive impairment
# Project Home Base: How Berto Came Indoors After 20 Years of Sidewalk Sleeping
# Decision letter: Cell autonomous regulation of hippocampal circuitry via Aph1b-γ-secretase/neuregulin 1 signalling
# Profiling the subjective effects of Δ<sup>9</sup>‐tetrahydrocannabinol using visual analogue scales
# Schizophrenia
# Psychotropic and General Drug Use by Mentally Retarded Persons: A Test of the Status Model of Drug Use
# Adding psychotherapy to antidepressant medication in depression and anxiety disorders: a meta-analysis
# Association of Anxiety Disorders and Depression With Incident Heart Failure
# Efficacy and safety of pharmacotherapy in cancer-related psychiatric disorders across the trajectory of cancer care: A review
# Resilience, depressed mood, and menopausal symptoms in postmenopausal women
# Trends in pharmacotherapy in patients referred to a bipolar specialty clinic, 2000–2011
# Symptoms of the Anxiety Disorders in a Perinatal Psychiatric Sample
# Psychotropic Prescribing for Persons With Intellectual Disabilities and Other Psychiatric Disorders
# Lithium in the Prevention of Suicide in Mood Disorders: Updated Systematic Review and Meta-analysis
# What&amp;rsquo;s in the pipeline? Drugs in development for autism spectrum disorder
# The Clinician’s Guide to Autism
# Links between occupational activities and depressive mood in young adult populations
# Gabapentin for Substance Use Disorders: Is it Safe and Appropriate?
# Long-acting injectable depot naltrexone use in the Veterans' Health Administration: A national study
# Two cases of mild serotonin toxicity via 5-hydroxytryptamine 1A receptor stimulation
# Is There a Role for Antidepressant and Antipsychotic Pharmacogenetics in Clinical Practice in 2014?
# Psychotropic medication monitoring checklists: use and utility for children in residential care.
# Response to Carnahan
# Medical comorbidity in youth with bipolar disorder: prevalence and implications for outcome
# CYP2D6: clinical implications in neuropsychiatry
# Workers’ psychological distress, depression, and burnout symptoms: associations with diurnal cortisol profiles
# CALM Pregnancy: results of a pilot study of mindfulness-based cognitive therapy for perinatal anxiety
# Characteristics and the trajectory of psychotropic medication use in general and antipsychotics in particular among adults with an intellectual disability who exhibit aggressive behaviour
# How MDMA's Pharmacology and Pharmacokinetics Drive Desired Effects and Harms
# Prolonged ketamine infusion as a therapy for complex regional pain syndrome: synergism with antagonism?
# Dual Disorders
# Alterations in circadian rhythms are associated with increased lipid peroxidation in females with bipolar disorder
# The Effect of Two Benzodiazepine Receptor Agonist Hypnotics on Sleep-Dependent Memory Consolidation
# Hypomania spectrum disorder in adolescence: a 15-year follow-up of non-mood morbidity in adulthood
# Mental Disorders and Coronary Heart Disease Risk
# Effect of Age on the Profile of Psychotropic Users: Results from the 2010 National Ambulatory Medical Care Survey
# Effects of small-scale, home-like facilities in dementia care on residents’ behavior, and use of physical restraints and psychotropic drugs: a quasi-experimental study
# Prevalence and correlates of psychotropic drug use in community-dwelling people with young-onset dementia: the NeedYD-study
# The Utilization Pattern and Costs Analysis of Psychotropic Drugs at a Neuropsychiatric Hospital in Nigeria
# A case–control study regarding relative factors for behavioural and psychological symptoms of dementia at a <scp>C</scp>anadian regional long‐term extended care facility: a preliminary report
# The entropic brain: a theory of conscious states informed by neuroimaging research with psychedelic drugs
# Substance abuse and psychosis. The strange case of opioids.
# Anticipatory nausea and vomiting due to chemotherapy
# The cannabinoid receptor 1 associates with NMDA receptors to produce glutamatergic hypofunction: implications in psychosis and schizophrenia
# Hallucinogenic 5-HT2AR agonists LSD and DOI enhance dopamine D2R protomer recognition and signaling of D2-5-HT2A heteroreceptor complexes
# Psychiatric comorbidity in the treatment of patients with inflammatory bowel disease
# Pharmacology of Hallucinations: Several Mechanisms for One Single Symptom?
# Adding Psychotherapy to Antidepressant Medication in Depression and Anxiety Disorders: a Meta-Analysis
# The behavioral effects of acute Δ9-tetrahydrocannabinol and heroin (diacetylmorphine) exposure in adult zebrafish
# Acceptance and Commitment Therapy for Management of Suicidal Patients: A Pilot Study
# History and Future of the Multidisciplinary Association for Psychedelic Studies (MAPS)
# First-Episode Psychosis: An Inflammatory State?
# Dermatologic Side Effects of Psychotropic Medications
# Pharmacogenomic Testing and Personalized Treatment of Depression
# Physical activity and depressive symptoms in older adults
# Indian Psychiatric Society multicentric study: Prescription patterns of psychotropics in India
# Dopamine D2 heteroreceptor complexes and their receptor–receptor interactions in ventral striatum
# Pharmacological modulation of cognitive and behavioral symptoms in patients with dementia due to Alzheimer's disease
# CNS drug development in Europe — Past progress and future challenges
# From Hofmann to the Haight Ashbury, and into the Future: The Past and Potential of Lysergic Acid Diethlyamide
# Psychedelic Drugs and the Problem of Experience
# Intellectual disability in India: Charity to right based
# MTHFR 1298A&gt;C is a risk factor for autism spectrum disorder in the Korean population
# Flashbacks and HPPD: A Clinical-oriented Concise Review.
# The Heffter Research Institute: Past and Hopeful Future
# Pharmacovigilance for psychiatrists: An introduction
# A study on drug prescribing pattern in psychiatry out-patient department from a tertiary care teaching hospital
# The Efficacy of Psychosocial Interventions for Adults in Contexts of Ongoing Man-Made Violence—A Systematic Review
# Psychotropic Polypharmacy for the Treatment of Bipolar Disorder in Taiwan
# Acute psychosis induced by isotretinoin
# Antenatal group therapy improves worry and depression symptoms.
# Depression and infertility in women seeking bariatric surgery
# Transforming Trajectories for Traumatized Children
# Psychotropic drugs and driving: prevalence and types
# The Effect of MDMA-Induced Anxiety on Neuronal Apoptosis in Adult Male Rats' Hippocampus
# Life-long consequences of juvenile exposure to psychotropic drugs on brain and behavior
# Low-Dose Caffeine May Exacerbate Psychotic Symptoms in People With Schizophrenia
# Effects of psychotropic drugs on brain plasticity in humans
# Successful Treatment of Catatonia in a Young Man With Schizophrenia and Progressive Diffuse Cerebral Atrophy
# Preferences for participation in shared decision making of psychiatric outpatients with affective disorders
# Current State of Evidence for Medication Treatment of Preschool Internalizing Disorders
# Prescribing pattern of antidepressant drugs in a te rtiary care hospital of eastern India
# Salvinorin A decreases mortality and improves neurological outcome in a neonatal mouse hypoxia model.
# [Trends of psychotropic medication use among children and adolescents in Japan data from the national insurance claims database between 2002 and 2010].
# Synthetic Cannabis Substances (SPS) Use and Hallucinogen Persisting Perception Disorder (HPPD): Two Case Reports.
# Successful Treatment of Dopamine Dysregulation Syndrome With Valproic Acid
# From pre-operative comorbidities to post-operative cognitive dysfunction: The challenging face of geriatric anaesthesia
# Augmentation Strategies in Patients with Schizophrenia Who Show Partial Response to Clozapine Treatment
# Bhang - beyond the purview of the narcotic drugs and psychotropic substances act
# Presidential Address: Partnering for the World's Children
# Lacosamide-Induced Tactile Hallucinations in a Patient With Complex Partial Seizures
# Long-Term Duloxetine Withdrawal Syndrome and Management in a Depressed Patient
# Medication use in community-dwelling older people: pharmacoepidemiology of psychotropic utilisation
# Gender differences in the prevalence and correlates of psychotropic medication use among older adults in Israel.
# Epilepsy and its Management in Relation to Psychiatry
# Psychiatric symptom differences in people with schizophrenia associated with substantial lifetime substance use but no current substance use disorder
# Emergence of kleptomania during treatment for obsessive compulsive disorder with fluvoxamine
# Deranged serum cholesterol levels in first episode mania
# Prolactin response to buspirone is not impaired in drug-naïve first episode patients with major depressive disorder
# Control of Mania With Chelation-Only in a Case of Wilson’s Disease
# Bupropion-Related Sexual Dysfunction and Possible Management in a Fresh Patient With Major Depressive Disorder
# Metacognition Training for Schizophrenia: A French Pilot Study
# Epistatic Interactions between CREB and CREM Variants in Affective Disorder
# Review of confounding effects on perfusion measurements
# Sex-Specific Substance Abuse Treatment for Female Healthcare Professionals: Implications
# Typology of sleep medication users and associated mental health and substance use from a Montreal epidemiological study.
# Hallucinogens
# Not Just Another Antipsychotic-for-Conduct-Problems Trial
# Factors associated to salivary flow alterations in dry mouth female patients
# Tuberous Sclerosis Presenting as Psychosis in an Adolescent Patient
# The Relief of Leukocytopenia Within 1 Month After Switching Risperidone to Amisulpride
# Mania-Like Symptoms in a Patient With Bartter Syndrome
# A Case Report of Blonanserin-Induced Hyponatremia
# [Psychotropic-associated sexual dysfunctions: a survey of clinical pharmacology and medication-associated practice].
# Peyote
# Treating Sexual Offenders
# Ethics Commentary: Ethics in Psychopharmacology Practice
# Plenary Study Shows Quick Method to Screen for Depression in Cancer Patients
# EPA-1652 – Sexuality and emotional life in people with severe long-term mental disorders
# Citalopram in Agitated and Delusional Demented Patients Who Failed Treatment With Antipsychotic Agents
# Exacerbation of Psychotic Symptoms due to Benzodiazepine Withdrawal
# [Features of the immune system and the risk of endogenous psychosis at juvenile age].
# PSILOCYBIN RESEARCH AT JOHNS HOPKINS: A 2014 REPORT
# Course, Treatment, and Outcome of Severe Mental Illnesses
# Ketamine for Treatment-Resistant Depression: Ready or Not for Clinical Use?
# Social Workers' Perspectives of Psychotropic Drug Use on Children and Adolescents
# Why should the fictional narrative permeate the death experience in medicine: A glance at Lev Tolstoy′s " Death of Ivan Illych" through Merleau Ponty′s phenomenological overtures
# The Human Gut Microbiome: A Physiological System Approach
# Consideraciones hacia los psicofármacos en profesionales y estudiantes de medicina en España, y en profesionales de la medicina en México y en Colombia : un estudio comparativo: un estudio comparativo
# Атипичные антипсихотики: больше сходств или различий? Теоретические предпосылки (часть 2)
# EPA-1211 – Role of 5-HT2a and mglu2 as a gpcr heterocomplex in antipsychotic action
# Синтетические и естественные каннабиноиды, трава дикорастущей конопли (марихуана, каннабис), гашиш, спайс, «Арома микс», манага: фармакологические эффекты при курении и приеме внутрь
# The Peyote Road: Religious Freedom and the Native American Church by Thomas C. Maroukis
# EPA-0890 – Effects of prenatal exposure to psychotropic medication on neonatal outcomes: the role of the psychiatric - obstetric liaison consultation
# EPA-1536 - Primary polydipsia and psychosis: diagnostic and therapeutic challenge: a case report
# EPA-0070 – Ganglioglioma and psychosis - an unusual association
# EPA-1306 - Prescribing for inpatients with borderline personality disorder
# EPA-0872 – Personal genomic profiles as a tool to guide therapy selection in a multiple chemical sensitivity: a case report
# The Amen Anti-Addiction Intervention: Theoretical Foundations of a Novel Neurotrophic Protocol for the Prevention and Treatment of Addiction
# Clinical Psychopharmacology of Eating Disorders: A Research Update
# EPA-0207 - Suicide prevention and pharmacological treatment
# A Comparison of Pharmacotherapy in Inpatients with Major Depressive Disorders Between Patients With Single Episodes and Patients With Recurrent Episodes
# A Comparison of Sexual Dysfunctions in Female Patients with Major Depressive Disorder and Panic Disorder
# EPA-1801 – Diagnosis, management and referrals to old age liaison psychiatry of delirium in a general hospital
# EPA-1457 – Cognitive functioning in major psychoses: delineating diagnostic continuity and discontinuity
# Incorporating Religion into Psychiatry: Evidenced–Based Practice, Not a Bioethical Dilemma
# Patología dual en trastornos de ansiedad: recomendaciones en el tratamiento farmacológico Dual diagnosis in anxiety disorders: pharmacologic treatment recommendations
# [The relationship between the duration of drug use and the bipolar disorder patients' sociodemographic and clinical characteristics].
# Nightmares and their treatment options
# Biological Therapies before the Introduction of Modern Psychotropic Drugs
# DRUG UTILIZATION STUDY OF ANTIPSYCHOTICS AND ITS COMMON ADR'S IN THE PSYCHIATRY OPD OF OHRC Original Article
# Letter to the Editor Sex and psychotropic drugs and relationship blues
# Hidden Dangers of Novel Psychostimulant Abuse Revealed using Danio rerio as a Model of Neurodevelopmental Toxicity
# Psycho-Oncologyedited by WiseThomas N., M.D., BiondiMassimo, M.D., and CostantiniAnna, Ph.D. Washington, DC, American Psychiatric Publishing, 2013, 376 pp., $74.00.
# PsychotropicPrescribingfor PersonsWithIntellectualDisabilities andOtherPsychiatricDisorders
# [Challenging behaviour in patients with intellectual disability].
# Survey of one-day psychotropic drug use of 257 hospitalized psychotic patients
# Clinical observation of aripiprazole orally disintegrating tablets on weight gain and prolactin increase caused by risperidone and sulpiride
# Психические расстройства у пациентов с заболеваниями системы крови: аспекты диагностики и лечения
# Inpatient utilization of psychotropic drugs: A time- point survey of psychiatry in a mental hospital of zhongshan city
# Risk Factors for Cerebrovascular Disorders and Psychotropic Drugs for Mental Disordered Hospitalized Patients
# [Role of glycogen synthase kinase-3β in the pathogenesis of mental disorders].
# A Postmodern Crisis of Irish Masculinity — Patrick McCabe’s Winterwood (2006)
# [Current evaluation of teratogenic and fetotoxic effects of psychotropic drugs].
# Treating Mood Disorders
# ARTIGO ORIGINAL / ORIGINAL ARTICLE / ORIGINALE Clinical and epidemiological characteristics of users of Day Hospital Caracterização clínica e epidemiológica dos usuários do Hospital-Dia Caracterización clínica y epidemiológica de losusuariosdel Hospital de Día
# Антидепрессанты в фокусе лекарственной токсикологии
# Hypothalamic-pituitary-adrenal axis dysfunction: An early marker of psychosis vulnerability?
# Атипичные антипсихотики: больше сходств или различий? Теоретические предпосылки (часть 1)
# Necesidades de los cuidadores de pacientes con deterioro cognitivo: Lo que necesitan versus lo que les ofrecemos
# REM Sleep Behavior Disorder
# Psychiatric comorbidity in the treatment of patients with inflammatory bowel disease
# PROTOCOL: Cognitive‐behavioural treatment for amphetamine‐type stimulants (ATS) use disorders
# Review of confounding effects on perfusion measurements
# CSM 2014 Orthopaedic and Sports Physical Therapy Section Programming
# The Amen Anti-Addiction Intervention: Theoretical Foundations of an Alternative Protocol for the Prevention and Treatment of Addiction
# Total number of results fetched: 7166
# Done. File saved to /content/psychadelics.csv

# %%
import os
import pandas as pd
import requests
import nltk
from collections import namedtuple
from nltk.corpus import brown
import time
import re
import urllib.parse

nltk.download('brown')

# Define helper functions
def toAbstract(p):
    """
    Extract the abstract from the paper.
    """
    return p.get('abstract', '')

def is_en(text, bc_brown, threshold=0.2):
    """
    Function to determine the papers' language.
    """
    if text is None or text == "":
        return 'EMPTY', 'NA'
    try:
        tok = set(re.findall(r"\w+", text.lower()))
        if len(tok) == 0:
            return 'EMPTY', 'NA'
        if len(tok & bc_brown.value) / len(tok) <= threshold:
            return 'PASS', 'non-en'
        else:
            return 'PASS', 'en'
    except Exception as e:
        return 'FAIL', str(e)

def getCitations(c):
    """
    Get citations from the paper.
    """
    if not c:
        return ''
    return '|'.join(c).replace('https://openalex.org/W', '')

def getAuthors(Authors):
    """
    Get authors from the paper.
    """
    return '|'.join([a['author']['id'].replace('https://openalex.org/A', '') for a in Authors if 'id' in a['author']])

def getConcepts(Concepts):
    """
    Get concepts from the paper.
    """
    return '|'.join([c['id'].replace('https://openalex.org/C', '') for c in Concepts])

# Initialize parameters
cursor = '*'
papersDict = []

# Prepare for API requests
Brown = namedtuple("Brown", field_names=['value'])
bc_brown = Brown(value=set([x.lower() for x in brown.words()]))
headers = {'email': 'avahomiar@gmail.com'}
search_term = '((((mood) OR (depress*) OR (affective disorder)) OR ((psychosis) OR (schizo*) OR (psychotic)) OR ((anxiety) OR (anxious))) AND ((psychedelic) OR (hallucinogen) OR (entheogen) OR (hallucinogenic) OR (psychotropic)))'
publication_year_range = '2014-2024'
encoded_search_term = urllib.parse.quote(search_term)
baseUrl = f'https://api.openalex.org/works?filter=title_and_abstract.search:{encoded_search_term},publication_year:{publication_year_range}&sort=publication_year:desc'

# Create the directory
output_dir = '/content'
os.makedirs(output_dir, exist_ok=True)

# Fetch and process articles
while cursor:
    full_url = f"{baseUrl}&per_page=100&cursor={cursor}"
    print(f"Fetching results from: {full_url}")

    response = requests.get(full_url, headers=headers)

    if response.status_code == 200:
        try:
            theJson = response.json()
        except requests.exceptions.JSONDecodeError:
            print(f"Error decoding JSON response. Status code: {response.status_code}")
            print("Response content:", response.text)
            break

        if 'results' in theJson and theJson['results']:
            for p in theJson['results']:
                abstract = toAbstract(p)
                title = p.get('title', '')
                if title is None:
                    title = ''
                title = title.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                pub_date = p.get('publication_date', '')
                pub_year = p.get('publication_year', '')
                passed, lang = is_en(title + ' ' + abstract, bc_brown)
                if lang != 'non-en':
                    papersDict.append({
                        'PaperId': p['id'].replace('https://openalex.org/W', ''),
                        'PaperTitle': title,
                        'Citations': getCitations(p.get('referenced_works', [])),
                        'coFoS': getConcepts(p.get('concepts', [])),
                        'Authors': getAuthors(p.get('authorships', [])),
                        'Abstract': abstract,
                        'Lang': 'en',
                        'PubYear': pub_year,
                        'PubDate': pub_date
                    })
            cursor = theJson['meta'].get('next_cursor', None)
        else:
            cursor = None

        # Pause to avoid rate limiting
        time.sleep(1)
    else:
        print(f"Request failed with status code {response.status_code}")
        break

df2 = pd.DataFrame(papersDict)
output_file_path = os.path.join(output_dir, 'moodpsychosispsychadelics.csv')
df2.to_csv(output_file_path, index=False)

print(f'Done. File saved to {output_file_path}')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=*
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNzE2NjgxNjAwMDAwLCA4OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTkwNTIyMjAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNzExOTI5NjAwMDAwLCA5Ni4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTEyNjQ0NzcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNzA4Mzg3MjAwMDAwLCA5MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTE5NjYzNDInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNzA0MDY3MjAwMDAwLCA5Ni4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTE0OTM4MjUnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNzAxODIwODAwMDAwLCA4NS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODk0NDI3ODEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjk4Nzk2ODAwMDAwLCA3NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODg4MDcyMTknXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjk1NjAwMDAwMDAwLCA5OS4wLCAxNywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzg3MDA3OTgwJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjkxNTM5MjAwMDAwLCA5OS4wLCAxNywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzg1Njk3NTAzJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjg3OTEwNDAwMDAwLCA3NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODIzOTY0MTInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjgzMDcyMDAwMDAwLCAxMDAuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM2Nzg1NzAyNSddIg==
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjc4OTI0ODAwMDAwLCA4NS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMjc2MTY2NDQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjc3NjI4ODAwMDAwLCA3NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODU2Njk0MDEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjcyOTYzMjAwMDAwLCA4NS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMTM2NDcyMzMnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjcyNTMxMjAwMDAwLCA3NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMTM2MzkyODgnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjY4MTI0ODAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMDg4MzQ2MDQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjY0NTgyNDAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMDQ2MzIxOTEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjYwMjYyNDAwMDAwLCA4OC4wLCA1LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTA5NzU4NzEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjU1ODU2MDAwMDAwLCA3NC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyODMyNjYzMzQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjUzNDM2ODAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTMwNjcwNzAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjQ4NzcxMjAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMjQyODMwMzcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjQ0MTkyMDAwMDAwLCA3NC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMTA4NjczMjQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjQwOTk1MjAwMDAwLCA4Ni4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMjY0OTUwOTknXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjQwOTk1MjAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTQ1NTI4MzgnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjM1ODExMjAwMDAwLCA4NS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMDM1NDg0NTMnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjMyOTYwMDAwMDAwLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMDM5Mjk4MDEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjI3Nzc2MDAwMDAwLCA5OC4wLCAzNCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyOTUzMjgwMDkyJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjIzNzE1MjAwMDAwLCA5Ny4wLCAyOCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMTcxMzg0ODc3J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjE5ODI3MjAwMDAwLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzMwNTI5MjcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjE1NTA3MjAwMDAwLCA4OC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMzUzMDUzMTYnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjExMTg3MjAwMDAwLCAxMDAuMCwgOTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyMjgwMTE5MiddIg==
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjA5NDU5MjAwMDAwLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjc1MjA4MzInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjA2NzgwODAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjY5MDM1MTcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNjAxNTEwNDAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDA4Nzc4ODEnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTk2MjQwMDAwMDAwLCA3OS4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDk2NTM2NTInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTkwOTY5NjAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMzA3NzEzNzcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTg1Njk5MjAwMDAwLCA3Mi4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMTQ3ODIzODUnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTgwMTY5NjAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDM4Mzk4ODInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTc3ODM2ODAwMDAwLCA2NC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMzQzODg2MjcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTcyODI1NjAwMDAwLCA4My4wLCA1LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5ODc1Mzg3MzAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTY3Mjk2MDAwMDAwLCA4Mi4wLCA1LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5MjE2MjkxNzInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTU5NjA2NDAwMDAwLCAxMDAuMCwgMTIzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NDg5MjQ0MDQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTU0MDc2ODAwMDAwLCA3Mi4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzczNzAzNTAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTQ4OTc5MjAwMDAwLCA3Mi4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5MjE0Nzc2MjAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTQ2MzAwODAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5ODIxMTU3MzMnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTQxNDYyNDAwMDAwLCA4OC4wLCAxMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyODk5NzAyOTYwJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTM2Mjc4NDAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4OTExMzk3ODcnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTMwNDAzMjAwMDAwLCA5Mi4wLCAxOSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyODA0MTMxNzM1J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTI1MTMyODAwMDAwLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3OTc2MzE2MjInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTE5MTcxMjAwMDAwLCA5My4wLCAyMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNzg3MzczNjM1J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTE0NzY0ODAwMDAwLCA3My4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4MDg0MjE4NjAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTA5NDk0NDAwMDAwLCA5Ny4wLCA0NSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNjI2MTQ1NTI4J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNTAyODQxNjAwMDAwLCA4OS4wLCAxMiwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNzQ5MDg2MzgzJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDk2Mjc1MjAwMDAwLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3OTE3MzY1MDAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDkxMDA0ODAwMDAwLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3Mjg2NTU5MjAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDgzMjI4ODAwMDAwLCAxMDAuMCwgMTY0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1MTcxNDExNDMnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDgyOTY5NjAwMDAwLCA4NC4wLCA1LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDQxMzIxNjYnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDc1MjgwMDAwMDAwLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1MzMxMzA4MjMnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDY3MzMxMjAwMDAwLCA4OS4wLCAxMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMjkzMzA4MzQ5J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDU5NDY4ODAwMDAwLCA5My4wLCAyMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNDAwMDg0MjgyJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDU0Mjg0ODAwMDAwLCA5MS4wLCAxNiwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTczMzU3MTk2J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDUxNjA2NDAwMDAwLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzNDM0Mjk5MjQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDQ2MzM2MDAwMDAwLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE4MzQyNjY0MjInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDM4OTkyMDAwMDAwLCA4OC4wLCAxMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTEzMjkzNjQzJ10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDMwNDM4NDAwMDAwLCA4Ni4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNzM1NTM2NDInXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDI1MTY4MDAwMDAwLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI0NzI0MTg0NjUnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDIwMDcwNDAwMDAwLCA3OS4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzNDQyMjI2NTQnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDE0ODAwMDAwMDAwLCA3NS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE5NzM0ODM4ODgnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxNDA2ODUxMjAwMDAwLCA5Ny4wLCA1OSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDAwMDgzMjU1J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxMzk4OTAyNDAwMDAwLCA2OC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMTM0MjAwNzAnXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxMzkxMjEyODAwMDAwLCA5Ny4wLCA1MCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDMzMjE3OTU1J10i
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxMzg4NTM0NDAwMDAwLCA3OC4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxMDUwNzU4OTknXSI=
# Fetching results from: https://api.openalex.org/works?filter=title_and_abstract.search:%28%28%28%28mood%29%20OR%20%28depress%2A%29%20OR%20%28affective%20disorder%29%29%20OR%20%28%28psychosis%29%20OR%20%28schizo%2A%29%20OR%20%28psychotic%29%29%20OR%20%28%28anxiety%29%20OR%20%28anxious%29%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29%29,publication_year:2014-2024&sort=publication_year:desc&per_page=100&cursor=IlsxMzg4NTM0NDAwMDAwLCA2OC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMDQyMDY1NjgnXSI=
# Done. File saved to /content/moodpsychosispsychadelics.csv

# %% [markdown]
# original openalex code

# %%
import pandas as pd
import requests
import json
from nltk.corpus import brown
from collections import namedtuple
import nltk

# %%
def toAbstract(s):
    if s == None:
        return ''
    if not 'abstract_inverted_index' in s:
        return ''
    s = s['abstract_inverted_index']
    vocab = []
    #s = str(json.loads(s))
    try:
        invIdx = s #["InvertedIndex"]
        for iidx in invIdx.items():
            for i in iidx[1]:
                vocab.append((iidx[0], i))
        vocab.sort(key=lambda x:x[1])
        retS = ''
        for x in range(len(vocab)):
            retS = retS + vocab[x][0] + ' '
        #return re.sub(r'''(?x)(?:\s+)''', " ", " ".join([x[0] for x in vocab]))
        return retS.replace('\n\r', ' ').replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    except:
        return ''

def is_en(text, bc_brown, threshold=0.2):
    """
    Function to determine the papers' language
    PARAM text: receiving some text (should be title + abstract text)
    RETURN language: language code, an exception or empty
    RETURN return_code: PASS, FAIL or EMPTY
    """

    if text is None or text == "":
        # text is an empty stirng
        language = 'NA'
        return_code = 'EMPTY'
    else:
        # text is a non empty string
        try:
            tok = set(re.findall(r"\w+", text.lower()))

            if len(tok) <= 0:
                # no tokens extracted - parse as empty
                language = 'NA'
                return_code = 'EMPTY'
            elif len(tok & bc_brown.value) / len(tok) <= threshold:
                # tokens extracted but too few are english terms
                language = 'non-en'
                return_code = 'PASS'
            else:
                # tokens extracted and enough are english terms
                language = 'en'
                return_code = 'PASS'

        except Exception as e:
            # something bad happened
            language = f"{e}"
            return_code = 'FAIL'

    return return_code, language

def getCitations(c):
    if c == None or c == '':
        return ''
    return str('|').join(c).replace('https://openalex.org/W', '')

def getAuthors(Authors):
    ret = ''
    for a in Authors:
        if ret == '':
            if 'id' in a['author']:
                ret = str(a['author']['id']).replace('https://openalex.org/A', '')
        else:
            if 'id' in a['author']:
                ret += '|' + str(a['author']['id']).replace('https://openalex.org/A', '')
    return ret

def getConcepts(Concepts):
    ret = ''
    for c in Concepts:
        if ret == '':
            ret = c['id'].replace('https://openalex.org/C', '')
        else:
            ret += '|' + c['id'].replace('https://openalex.org/C', '')
    return ret

def calculate_total_pages(total_results, page_size):
    return total_results // page_size + (total_results % page_size > 0)

# %%
import os
import pandas as pd
import requests
import nltk
from collections import namedtuple
from nltk.corpus import brown
import time
import re

nltk.download('brown')

# Define helper functions
def toAbstract(p):
    return p.get('abstract', '')

def is_en(text, bc_brown, threshold=0.2):
    if text is None or text == "":
        return 'EMPTY', 'NA'
    try:
        tok = set(re.findall(r"\w+", text.lower()))
        if len(tok) == 0:
            return 'EMPTY', 'NA'
        if len(tok & bc_brown.value) / len(tok) <= threshold:
            return 'PASS', 'non-en'
        else:
            return 'PASS', 'en'
    except Exception as e:
        return 'FAIL', str(e)

def getCitations(c):
    if not c:
        return ''
    return '|'.join(c).replace('https://openalex.org/W', '')

def getAuthors(Authors):
    return '|'.join([a['author']['id'].replace('https://openalex.org/A', '') for a in Authors if 'id' in a['author']])

def getConcepts(Concepts):
    return '|'.join([c['id'].replace('https://openalex.org/C', '') for c in Concepts])

# Initialize parameters
cursor = '*'
sample_size = 50000
papersDict = []
current_page = 1

Brown = namedtuple("Brown", field_names=['value'])
bc_brown = Brown(value=set([x.lower() for x in brown.words()]))
headers = {'email': 'avahomiar@gmail.com'}
baseUrl = 'https://openalex.org/works?page=1&filter=title_and_abstract.search%3A%28%28mood%29%20OR%20%28depress%2a%29%20OR%20%28affective%20disorder%29%29%20AND%20%28%28psychosis%29%20OR%20%28schizo%2a%29%20OR%20%28psychotic%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29,publication_year%3A2014-2024&sort=publication_year%3Adesc'

# Create the directory if it does not exist
output_dir = './output'
os.makedirs(output_dir, exist_ok=True)

# Fetch and process articles
while cursor:
    full_url = f"{baseUrl}&per_page=100&cursor={cursor}"
    print(f"Fetching results from: {full_url}")

    r = requests.get(full_url, headers=headers)

    if r.status_code == 200:
        try:
            theJson = r.json()
        except requests.exceptions.JSONDecodeError:
            print(f"Error decoding JSON response. Status code: {r.status_code}")
            print("Response content:", r.text)
            break

        if 'results' in theJson and theJson['results']:
            for p in theJson['results']:
                abstract = toAbstract(p)
                title = p.get('title', '')
                if title is None:
                    title = ''
                title = title.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                pub_date = p.get('publication_date', '')
                pub_year = p.get('publication_year', '')
                passed, lang = is_en(title + ' ' + abstract, bc_brown)
                if lang != 'non-en':
                    papersDict.append({
                        'PaperId': p['id'].replace('https://openalex.org/W', ''),
                        'PaperTitle': title,
                        'Citations': getCitations(p.get('referenced_works', [])),
                        'coFoS': getConcepts(p.get('concepts', [])),
                        'Authors': getAuthors(p.get('authorships', [])),
                        'Abstract': abstract,
                        'Lang': 'en',
                        'PubYear': pub_year,
                        'PubDate': pub_date
                    })
            cursor = theJson['meta'].get('next_cursor', None)
        else:
            cursor = None

        # Pause to avoid rate limiting
        time.sleep(1)
    else:
        print(f"Request failed with status code {r.status_code}")
        break

df2 = pd.DataFrame(papersDict)
output_file_path = os.path.join(output_dir, 'openalex_moodpsychosispsychadelics.csv'
df2.to_csv(output_file_path, index=False)

print(f'Done. File saved to {output_file_path}')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Fetching results from: https://openalex.org/works?page=1&filter=title_and_abstract.search%3A%28%28mood%29%20OR%20%28depress%2a%29%20OR%20%28affective%20disorder%29%29%20AND%20%28%28psychosis%29%20OR%20%28schizo%2a%29%20OR%20%28psychotic%29%29%20AND%20%28%28psychedelic%29%20OR%20%28hallucinogen%29%20OR%20%28entheogen%29%20OR%20%28hallucinogenic%29%20OR%20%28psychotropic%29%29,publication_year%3A2014-2024&sort=publication_year%3Adesc&per_page=100&cursor=*
# Error decoding JSON response. Status code: 200
# Response content: <!doctype html><html lang="en"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" href="/favicon.png"><title>OpenAlex</title><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:100,300,400,500,700,900"><link href="https://fonts.googleapis.com/css2?family=Dosis:wght@100;200;300;400;500;600;700;800;900&display=swap" rel="stylesheet"><script defer="defer" data-domain="openalex.org" src="https://plausible.io/js/script.outbound-links.js"></script><script defer="defer" src="/js/chunk-vendors.238cdac7.js"></script><script defer="defer" src="/js/app.431d1a19.js"></script><link href="/css/chunk-vendors.e518b331.css" rel="stylesheet"><link href="/css/app.03bbf1aa.css" rel="stylesheet"></head><body><noscript><strong>We're sorry but ourresearch-website-2 doesn't work properly without JavaScript enabled. Please enable it to continue.</strong></noscript><div id="app"></div></body></html>
# Done. File saved to ./output/openalex_moodpsychosispsychadelics.csv
